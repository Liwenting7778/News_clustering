# %% [markdown]
# <a href="https://colab.research.google.com/github/Liwenting7778/News_clustering/blob/main/news_cluste2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 数据预处理：读取json文件，分词，去除标点符号后存入CSV文件（保留了"keywords", "title", "desc", "content"）

# %%
#解压
import zipfile
zf = zipfile.ZipFile('./data/new2016zh.zip')
print(zf.namelist())
zf.extractall()
zf.close()


#读取json文件
import json
with open('./data/news2016zh_train.json', 'r', encoding="utf-8") as f:
    lines = f.readlines()

#数据预处理，并存到csv文件
import csv
import os
import jieba
import re

stopwords = [i.strip() for i in open('./cn_stop_words.txt',"r", encoding="utf-8").readlines()]

#分词并且去除停用词
def pretty_cut(sentence):
    cut_list = jieba.lcut(''.join(re.findall('[\u4e00-\u9fa5]', sentence)), cut_all=True)
    for i in range(len(cut_list) - 1, -1, -1):
        if cut_list[i] in stopwords:
            del cut_list[i]
    return cut_list

with open(os.path.join("./data/news2016zh_train.csv"), "w", encoding="utf-8", newline='') as g:
    writer = csv.writer(g)
    writer.writerow(["keywords", "title", "desc", "content"])
    for line in lines:
        news = json.loads(line)
        keywords = news["keywords"].strip(" ")
        title = news["desc"].strip(" ")
        desc = news["desc"].strip(" ")
        content = news["content"].strip(" ")
        cut_keywords = " ".join(pretty_cut(keywords))
        cut_title = " ".join(pretty_cut(title))
        cut_desc = " ".join(pretty_cut(desc))
        cut_content = " ".join(pretty_cut(content))
        writer.writerow([cut_keywords, cut_title, cut_desc, cut_content])

# %% [markdown]
# 导入必要的库

# %%
# !pip install umap-learn -i https://mirrors.ustc.edu.cn/pypi/web/simple
# !pip install hdbscan
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://mirrors.ustc.edu.cn/pypi/web/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting umap-learn
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/e1/eb/dca6cfd872e8542fb57dd56ff2d5d67baed270aee6db739c6414d8d5b3b5/umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 167 kB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/fa/bd/aa2c2f52e2152d99ddce9233b1260903094fec7db17600104058da439f05/pynndescent-0.5.7.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 391 kB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from umap-learn) (4.64.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=2167ae96010199735fbbeef3456a78446c9e2cad30fd4b4935f4035bc7238d72
#   Stored in directory: /root/.cache/pip/wheels/ab/08/f8/98388f3fdbfc43aac05c98a3bce079cd212640c1adbeb2b617
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=eff6effafcd2a7db427d15f4e7fec665f97296e0f335edcd9087c2dab1b63037
#   Stored in directory: /root/.cache/pip/wheels/9c/87/08/8032c8fdf442d43c7733dbb6129b48bc0c20c8046f26922dd8
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.7 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hdbscan
#   Downloading hdbscan-0.8.28.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 27.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (0.29.30)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.4.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from hdbscan) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->hdbscan) (3.1.0)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2342148 sha256=a99ffaf2d62e66fed70297911bec317daa20624905ed80512fc889969f020813
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
# Successfully built hdbscan
# Installing collected packages: hdbscan
# Successfully installed hdbscan-0.8.28
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 5.6 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 12.6 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 66.2 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (4.2.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 54.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 47.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.7.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (4.11.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=516beafd34ce888e5149b88000932465418a1c217864d8f2db3de7948469e4b6
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.19.2

# %%
import sys
import numpy as np
import pandas as pd
import jieba
import umap
import hdbscan
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# 读取文本

# %%
#加载google的云端硬盘
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/news2016zh_valid.csv')

# %%
data.head()
# Out:
#                            keywords  \
# 0  借鉴 篇 受欢迎 欢迎 校训 没有 一个 字 讲学 讲学习 学习
# 1      市民 淘宝 购物 一年 四度 忽悠 买货 容易 退货 难
# 2               统计 机械 电器 类 公司 市场 表现
# 3                  每日 技 四维 绕 杆 跑 练习
# 4               漫 展 活动 风云 小分 小分队 分队
#
#                                                title  \
# 0  知道 是因为 偶然 来到 世界 践行 一个 平凡 美丽 无私 梦想 而来 苦乐 逆 体验 来...
# 1  张女士 女士 提供 豆 皮 虫 尸 证据 照片 受访 受访者 供 图 淘宝 购物 一年 忽悠...
# 2      名称 代码 收盘 收盘价 日 涨跌 周 涨跌 月 涨跌 季 涨跌 深 华新 中联 中联重科
# 3  爱 高 体育 有趣 兼有 有料 校园 足球 足球资讯 资讯 平台 每日 分享 一招 足球 球...
# 4  期待 期待已久 已久 万圣 动漫 音乐 音乐节 终于 风云 动漫 社 动物 动物园 小分 小...
#
#                                                 desc  \
# 0  知道 是因为 偶然 来到 世界 践行 一个 平凡 美丽 无私 梦想 而来 苦乐 逆 体验 来...
# 1  张女士 女士 提供 豆 皮 虫 尸 证据 照片 受访 受访者 供 图 淘宝 购物 一年 忽悠...
# 2      名称 代码 收盘 收盘价 日 涨跌 周 涨跌 月 涨跌 季 涨跌 深 华新 中联 中联重科
# 3  爱 高 体育 有趣 兼有 有料 校园 足球 足球资讯 资讯 平台 每日 分享 一招 足球 球...
# 4  期待 期待已久 已久 万圣 动漫 音乐 音乐节 终于 风云 动漫 社 动物 动物园 小分 小...
#
#                                              content
# 0  知道 是因为 偶然 来到 世界 践行 一个 平凡 美丽 无私 梦想 而来 苦乐 逆 体验 来...
# 1  张女士 女士 提供 豆 皮 虫 尸 证据 照片 受访 受访者 供 图 淘宝 购物 一年 忽悠...
# 2  名称 代码 收盘 收盘价 日 涨跌 周 涨跌 月 涨跌 季 涨跌 深 华新 中联 中联重科 ...
# 3  爱 高 体育 有趣 兼有 有料 校园 足球 足球资讯 资讯 平台 每日 分享 一招 足球 球...
# 4  期待 期待已久 已久 万圣 动漫 音乐 音乐节 终于 风云 动漫 社 动物 动物园 小分 小...

# %%
#处理异常值
print("在 news 列中总共有 %d 个空值." % data['content'].isnull().sum())
data[data.isnull().values==True]#isnull返回一个布尔数组
data = data[pd.notnull(data['content'])]#保留非null的news

data['content']=data['content'].astype(str) #将数据类型都换成str
# Out:
# 在 news 列中总共有 1010 个空值.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# 创建句子嵌入

# %%
#创建语句嵌入
#model = SBert('paraphrase-multilingual-MiniLM-L12-v2')
# %%time
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
embeddings = model.encode(data['content'].tolist(), show_progress_bar=True)
# Out:
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Batches:   0%|          | 0/2369 [00:00<?, ?it/s]
# CPU times: user 2h 11min 58s, sys: 2min 18s, total: 2h 14min 16s
# Wall time: 2h 12min 28s

# %%
embeddings.shape
np.savetxt('/content/drive/MyDrive/embeddings_valid.txt', embeddings, fmt='%d')

# %% [markdown]
# 句子嵌入降维处理

# %%
sys.setrecursionlimit(1000000)
umap_embeddings = umap.UMAP(n_neighbors=25,
               n_components=10,
               min_dist=0.00,
               metric='cosine',
               random_state=2020).fit_transform(embeddings)

# %% [markdown]
#  利用HDBSCAN进行文档聚类

# %%
cluster = hdbscan.HDBSCAN(min_cluster_size=100,
                          metric='euclidean',
                          cluster_selection_method='eom', 
                          prediction_data=True).fit(umap_embeddings)

# %%
# Prepare data
umap_data = umap.UMAP(n_neighbors=15, 
                      n_components=2, 
                      min_dist=0.0,
                      metric='cosine').fit_transform(embeddings)

result = pd.DataFrame(umap_data, columns=['x', 'y'])
result['labels'] = cluster.labels_

# Visualize clusters
fig, ax = plt.subplots(figsize=(25, 15))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y, color='#BDBDBD', s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=0.05, cmap='hsv_r')
plt.colorbar()
plt.savefig("result1.png", dpi = 300)

# %% [markdown]
# c-TF-IDF

# %%
def c_tf_idf(documents, m, ngram_range=(1, 1)):
    my_stopwords =  [i.strip() for i in open('/content/drive/MyDrive/cn_stop_words.txt',encoding='utf-8').readlines()]
    """ Calculate a class-based TF-IDF where m is the number of total documents. """
    count = CountVectorizer(ngram_range=ngram_range, 
                            #tokenizer = lambda x : ' '.join(jieba.lcut(x)),
                            stop_words= my_stopwords).fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count

# %%
def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['Topic'])
                     .Doc
                     .count()
                     .reset_index()
                     .rename({"Topic": "Topic", "Doc": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

# %% [markdown]
# 计算每个主题下的TOP主题词

# %%
docs_df = pd.DataFrame(data['content'].tolist(), columns=["Doc"]) 
docs_df['Topic'] = cluster.labels_
docs_df['Doc_ID'] = range(len(docs_df))
docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

# %%
len(docs_per_topic.Doc.tolist())
# Out:
# 60

# %%
tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m = len(data))

# %%
top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20)
topic_sizes = extract_topic_sizes(docs_df); topic_sizes.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     Topic   Size
# 0      -1  34984
# 39     38   4815
# 5       4   4173
# 25     24   3730
# 38     37   3360
# 12     11   3158
# 55     54   1464
# 57     56   1165
# 49     48   1153
# 16     15   1109

# %%
#看看主题索引为18的主题下的主题词是哪些：
top_n_words[10]
# Out:
# [('彩票', 0.06713429909641198),
#  ('投注', 0.04521488013745179),
#  ('中奖', 0.044697440152287715),
#  ('奖金', 0.042848133956968903),
#  ('彩民', 0.04224212363822906),
#  ('号码', 0.0399842074351707),
#  ('色球', 0.03273749790945276),
#  ('大乐透', 0.03253731925746936),
#  ('体彩', 0.032186895840490386),
#  ('大奖', 0.032147792143402756),
#  ('大乐', 0.030675472318038043),
#  ('头奖', 0.030070335905655794),
#  ('双色球', 0.030031262398825417),
#  ('开奖', 0.02858084411707933),
#  ('双色', 0.025509472546166603),
#  ('开出', 0.021255853839865932),
#  ('福彩', 0.01895956790476815),
#  ('投注站', 0.018246749463893465),
#  ('追加', 0.017798376625089186),
#  ('竞猜', 0.017240523549676534)]

# %%
# 删除索引为-1的聚类簇群
top_n_words[-1]
from pprint import pprint
for i in list(range(len(top_n_words) - 1)):
    print('Most 20 Important words in TOPIC {} :\n'.format(i))
    pprint(top_n_words[i])
    pprint('***'*20)
# Out:
# Most 20 Important words in TOPIC 0 :
#
# [('股东', 0.025013614213879234),
#  ('表决', 0.023604370026441435),
#  ('董事', 0.023043074033778498),
#  ('股东大会', 0.01944619849949937),
#  ('议案', 0.018650535619570807),
#  ('董事会', 0.018444309533152112),
#  ('东大', 0.01832243288602126),
#  ('股份', 0.018068483461824658),
#  ('审议', 0.01553672963790957),
#  ('大会', 0.01397963112291974),
#  ('股份有限', 0.013820640971283717),
#  ('投票', 0.012835003480468942),
#  ('年度', 0.01235268154399561),
#  ('公告', 0.01223274828683492),
#  ('有限公司', 0.012224227838338394),
#  ('弃权', 0.0118878258660968),
#  ('会议', 0.011797205322416736),
#  ('本次', 0.011781005005124377),
#  ('有限', 0.011587254487795956),
#  ('监事', 0.01140488266238262)]
# '************************************************************'
# Most 20 Important words in TOPIC 1 :
#
# [('养老', 0.06697560673979519),
#  ('养老金', 0.039095040243853754),
#  ('老金', 0.03885772950078947),
#  ('养老保险', 0.029339102750193954),
#  ('退休', 0.02887281246914106),
#  ('年金', 0.025758693290130443),
#  ('保险', 0.02384305817061023),
#  ('缴费', 0.01803093366815918),
#  ('社保', 0.012993121472575584),
#  ('退休年龄', 0.01215522918543763),
#  ('入市', 0.012150475119643397),
#  ('参保', 0.01156482854074771),
#  ('职业', 0.010217254618670662),
#  ('事业单位', 0.010067639922694757),
#  ('延迟', 0.009047331505210601),
#  ('基本', 0.008591679686128164),
#  ('职工', 0.00859044983444866),
#  ('工伤', 0.00858000063648778),
#  ('单位', 0.00851452717124359),
#  ('待遇', 0.007604353685812457)]
# '************************************************************'
# Most 20 Important words in TOPIC 2 :
#
# [('教程', 0.22345653943379817),
#  ('组件', 0.08476777742523225),
#  ('视频教程', 0.07305752108093674),
#  ('视频', 0.05261088129304504),
#  ('路由', 0.050047474628163974),
#  ('路由器', 0.03461818764186178),
#  ('渲染', 0.03232894337036515),
#  ('创建', 0.030316961856421683),
#  ('基础教程', 0.027729663600014456),
#  ('嵌套', 0.025620584648463344),
#  ('课程', 0.024404828258737434),
#  ('示例', 0.02241232777773328),
#  ('滴答', 0.021907331608369877),
#  ('图图', 0.02037157378309549),
#  ('本系', 0.018942162279923326),
#  ('系列', 0.018715292455674427),
#  ('短视', 0.017936275926014985),
#  ('制作', 0.017425180513454923),
#  ('路径', 0.017340269254423453),
#  ('基础', 0.01712535644254924)]
# '************************************************************'
# Most 20 Important words in TOPIC 3 :
#
# [('茶叶', 0.033350559109214285),
#  ('咖啡', 0.03329105086612465),
#  ('普洱', 0.017661166344661836),
#  ('绿茶', 0.0169792460150256),
#  ('红茶', 0.01651676546475439),
#  ('喝茶', 0.012830470905119616),
#  ('普洱茶', 0.012715224994121916),
#  ('星巴克', 0.01152239583847716),
#  ('巴克', 0.010780821940333186),
#  ('冲泡', 0.010117547973409384),
#  ('乌龙', 0.010044939607317734),
#  ('乌龙茶', 0.009547278505511287),
#  ('茶文化', 0.0091821468518455),
#  ('饮茶', 0.008697254589466926),
#  ('龙井', 0.00842359381477409),
#  ('泡茶', 0.007673658798376185),
#  ('茶树', 0.007494726485455491),
#  ('大红袍', 0.0074908439152230055),
#  ('红袍', 0.007429509757517486),
#  ('花茶', 0.007288664618492921)]
# '************************************************************'
# Most 20 Important words in TOPIC 4 :
#
# [('搞笑', 0.015527073422293994),
#  ('儿歌', 0.013672971944820955),
#  ('熊出没', 0.012053251802007553),
#  ('源源', 0.010594933141373703),
#  ('幽默', 0.01015714319030272),
#  ('出没', 0.010053026841199303),
#  ('视频', 0.009804047605505633),
#  ('奥特曼', 0.009500069779994468),
#  ('奥特', 0.009455795876181321),
#  ('特曼', 0.008993285701080926),
#  ('舞蹈', 0.008834293072040818),
#  ('高清', 0.007664163279311083),
#  ('美女', 0.007053178680674881),
#  ('解说', 0.006641890091641406),
#  ('佩奇', 0.0064594290466465564),
#  ('蛋壳', 0.00625622600403447),
#  ('清版', 0.0062158865364495075),
#  ('成语', 0.006104846305820226),
#  ('完整版', 0.006073374780027308),
#  ('鸡蛋壳', 0.005990830966063933)]
# '************************************************************'
# Most 20 Important words in TOPIC 5 :
#
# [('混凝土', 0.013849604251671376),
#  ('设备', 0.011330451399984932),
#  ('密封', 0.011042552193205801),
#  ('过滤', 0.010088989999123506),
#  ('螺栓', 0.009970021593484563),
#  ('溅射', 0.009860830436571134),
#  ('法兰', 0.009818047336484788),
#  ('水器', 0.009724882472905266),
#  ('安装', 0.00959073300762343),
#  ('清洗', 0.008887988948911189),
#  ('纳米', 0.008277297361830404),
#  ('反渗透', 0.008166431873157746),
#  ('采用', 0.008059292983567149),
#  ('热水', 0.008048619942095757),
#  ('材料', 0.007791751378966739),
#  ('高压', 0.007737519160639217),
#  ('施工', 0.007670345433366906),
#  ('工作台', 0.0076206448945630705),
#  ('超净', 0.007570493348593879),
#  ('热水器', 0.007500444664532933)]
# '************************************************************'
# Most 20 Important words in TOPIC 6 :
#
# [('装修', 0.03049505755881105),
#  ('家具', 0.013913269516002795),
#  ('装饰', 0.0126138006990555),
#  ('卧室', 0.012379926194663412),
#  ('客厅', 0.011556005685277537),
#  ('设计', 0.010992843176138465),
#  ('空间', 0.010517872119713749),
#  ('阳台', 0.010346130420036551),
#  ('厨房', 0.010303630502222074),
#  ('户型', 0.009137846897590998),
#  ('瓷砖', 0.00906156998087767),
#  ('墙面', 0.009049676556241053),
#  ('地板', 0.008779002264418875),
#  ('家居', 0.008230728404242181),
#  ('风格', 0.008214823396781349),
#  ('室内', 0.007727620614534104),
#  ('沙发', 0.007409853823253382),
#  ('设计师', 0.007104024137598204),
#  ('施工', 0.007067279503473138),
#  ('衣柜', 0.006946465276698826)]
# '************************************************************'
# Most 20 Important words in TOPIC 7 :
#
# [('能源', 0.028360858234111306),
#  ('新能源', 0.024753189969067817),
#  ('电动', 0.01925395119032845),
#  ('充电', 0.016742142621170845),
#  ('电池', 0.01624231591515172),
#  ('发电', 0.012738741460201895),
#  ('汽车', 0.012509738461392852),
#  ('电动汽车', 0.01122155315797276),
#  ('光伏', 0.010864042437551326),
#  ('电力', 0.009875838021425517),
#  ('电动车', 0.009361132244314214),
#  ('电网', 0.009141904058689958),
#  ('电价', 0.008667623542175618),
#  ('动车', 0.008474706534893075),
#  ('太阳能', 0.008470185914839735),
#  ('补贴', 0.007646809617526489),
#  ('风电', 0.007168856023171735),
#  ('可再生', 0.006548002776111498),
#  ('再生能源', 0.006523646322654),
#  ('机组', 0.006514984618297626)]
# '************************************************************'
# Most 20 Important words in TOPIC 8 :
#
# [('狗狗', 0.04249570269637985),
#  ('宠物', 0.04149893985315525),
#  ('猫咪', 0.017807531534367187),
#  ('主人', 0.014478716015413994),
#  ('社区', 0.012950912116489912),
#  ('办事处', 0.009714788331768077),
#  ('流浪', 0.008862154940216367),
#  ('流浪狗', 0.008684107315024198),
#  ('小狗', 0.008679847381161171),
#  ('动物', 0.00866111884765835),
#  ('一只', 0.008258269946450396),
#  ('办事', 0.00790418844677231),
#  ('寄养', 0.007599265856263965),
#  ('小猫', 0.0071288754619837245),
#  ('宠物店', 0.006822471646336484),
#  ('金毛', 0.006671266434009834),
#  ('收容', 0.006194659653916121),
#  ('小区', 0.005549132596435444),
#  ('宠物医院', 0.005236308725701045),
#  ('哈士奇', 0.005223833638804141)]
# '************************************************************'
# Most 20 Important words in TOPIC 9 :
#
# [('刹车', 0.027872333455383275),
#  ('车辆', 0.016536348298106417),
#  ('轮胎', 0.01576290314309972),
#  ('驾驶', 0.015539015300946164),
#  ('制动', 0.01317244092488016),
#  ('行驶', 0.01272444936180463),
#  ('车主', 0.012020156865715535),
#  ('刹车片', 0.010509064015722281),
#  ('开车', 0.01043016231530484),
#  ('司机', 0.009769802920462213),
#  ('事故', 0.00950369242632024),
#  ('停车', 0.00895529976468672),
#  ('后车', 0.008221391273507551),
#  ('汽车', 0.0077288921418192155),
#  ('货车', 0.0076563977779414245),
#  ('车速', 0.007403444031744543),
#  ('前车', 0.0073017567088752315),
#  ('违章', 0.007016426711789389),
#  ('手刹', 0.0069154370400103795),
#  ('离合', 0.006849437665797272)]
# '************************************************************'
# Most 20 Important words in TOPIC 10 :
#
# [('彩票', 0.06713429909641198),
#  ('投注', 0.04521488013745179),
#  ('中奖', 0.044697440152287715),
#  ('奖金', 0.042848133956968903),
#  ('彩民', 0.04224212363822906),
#  ('号码', 0.0399842074351707),
#  ('色球', 0.03273749790945276),
#  ('大乐透', 0.03253731925746936),
#  ('体彩', 0.032186895840490386),
#  ('大奖', 0.032147792143402756),
#  ('大乐', 0.030675472318038043),
#  ('头奖', 0.030070335905655794),
#  ('双色球', 0.030031262398825417),
#  ('开奖', 0.02858084411707933),
#  ('双色', 0.025509472546166603),
#  ('开出', 0.021255853839865932),
#  ('福彩', 0.01895956790476815),
#  ('投注站', 0.018246749463893465),
#  ('追加', 0.017798376625089186),
#  ('竞猜', 0.017240523549676534)]
# '************************************************************'
# Most 20 Important words in TOPIC 11 :
#
# [('比赛', 0.016426418872986546),
#  ('球队', 0.012092572843541679),
#  ('赛季', 0.011173006015443342),
#  ('球员', 0.010512116859831019),
#  ('足球', 0.010410134140982302),
#  ('体育', 0.009130897444292766),
#  ('联赛', 0.00882842484037377),
#  ('冠军', 0.008133628593245297),
#  ('世界杯', 0.006982049524743565),
#  ('国足', 0.0068542663953514524),
#  ('球迷', 0.006460219119555992),
#  ('赛事', 0.006443596420155514),
#  ('决赛', 0.0062490166421614425),
#  ('主场', 0.0059485752290541994),
#  ('奥运', 0.00584067033563031),
#  ('教练', 0.005658050806417929),
#  ('进球', 0.005570453533046814),
#  ('俱乐部', 0.004933444037302595),
#  ('选手', 0.004691972479969793),
#  ('巴西', 0.004569004409232369)]
# '************************************************************'
# Most 20 Important words in TOPIC 12 :
#
# [('版权', 0.014798710034652334),
#  ('作者', 0.012216730361341164),
#  ('豆瓣', 0.011851398480253716),
#  ('文章', 0.010595312782735776),
#  ('点击', 0.009023851140272357),
#  ('转载', 0.008680019107404156),
#  ('阅读', 0.007764868460833222),
#  ('内存', 0.007535974356705716),
#  ('删除', 0.0073051633185391126),
#  ('赌场', 0.006819424199627819),
#  ('演讲集', 0.006700165336796911),
#  ('下载', 0.0066222820504855924),
#  ('原文', 0.006461719745780071),
#  ('盗版', 0.006425608572377441),
#  ('单词', 0.006335944786063399),
#  ('筹码', 0.0060298014832419365),
#  ('调用', 0.0059544005859370275),
#  ('兔子', 0.0059278613422784135),
#  ('留言', 0.00591089383267207),
#  ('二维', 0.005483125620806645)]
# '************************************************************'
# Most 20 Important words in TOPIC 13 :
#
# [('车型', 0.02311015571689087),
#  ('新车', 0.014096010819693737),
#  ('发动机', 0.014022761450216175),
#  ('动机', 0.013455322120328598),
#  ('发动', 0.013360025289918757),
#  ('全新', 0.011174411716774071),
#  ('汽车', 0.009580280001171147),
#  ('内饰', 0.009475710134334755),
#  ('车身', 0.009150567157838426),
#  ('动力', 0.008816803733912746),
#  ('配置', 0.008761905779004606),
#  ('变速', 0.008491934433137767),
#  ('外观', 0.008093962431246304),
#  ('销量', 0.00785215238698179),
#  ('奔驰', 0.007360284632365193),
#  ('变速箱', 0.0070539570231741055),
#  ('设计', 0.007015469992742745),
#  ('搭载', 0.006882203364474632),
#  ('采用', 0.006741782005920768),
#  ('座椅', 0.006633681312762198)]
# '************************************************************'
# Most 20 Important words in TOPIC 14 :
#
# [('万万', 0.03913050214492261),
#  ('搜狐', 0.0271327497255251),
#  ('报错', 0.022295524336159864),
#  ('座椅', 0.021810211701511782),
#  ('有奖', 0.02129480430997302),
#  ('经销商', 0.020840509588944144),
#  ('经销', 0.02053079714195346),
#  ('充足', 0.019171961641322215),
#  ('手动', 0.01734825596763373),
#  ('询价', 0.01573399871966166),
#  ('后排', 0.015558348097880668),
#  ('车型', 0.015558022703793362),
#  ('优惠', 0.015180067076256904),
#  ('汽车', 0.015074960009658266),
#  ('悬挂', 0.014941351954326781),
#  ('自动', 0.014382747997768794),
#  ('调节', 0.014357006045428949),
#  ('电动', 0.014245036427153917),
#  ('车身', 0.013655033148249804),
#  ('发动机', 0.013609800907198807)]
# '************************************************************'
# Most 20 Important words in TOPIC 15 :
#
# [('医院', 0.01683856239243652),
#  ('医疗', 0.015692551463285607),
#  ('医生', 0.009659839119187717),
#  ('药品', 0.008496034923886184),
#  ('患者', 0.008147047870584687),
#  ('医药', 0.007710831941853364),
#  ('中医', 0.007562138321814325),
#  ('医学', 0.0074334325527510795),
#  ('卫生', 0.0071088541641048135),
#  ('健康', 0.006808661489649401),
#  ('治疗', 0.006509472365789817),
#  ('手术', 0.006017077629112448),
#  ('临床', 0.0059878452090173255),
#  ('医保', 0.0056056013855798476),
#  ('医疗机构', 0.0049044295510095835),
#  ('病人', 0.004703725412162371),
#  ('医师', 0.004213242736886746),
#  ('疾病', 0.004013759697084717),
#  ('中医药', 0.004005266009735372),
#  ('公立', 0.003989652570060949)]
# '************************************************************'
# Most 20 Important words in TOPIC 16 :
#
# [('二维码', 0.031201516999929),
#  ('二维', 0.03104705213610017),
#  ('订阅', 0.02888561627923161),
#  ('简介', 0.028047634944203717),
#  ('别关', 0.027303462574043227),
#  ('识别', 0.02704180928566815),
#  ('免费', 0.02181836161137731),
#  ('女人', 0.020948067030099958),
#  ('信号', 0.01800913678332429),
#  ('关注', 0.014078737837449722),
#  ('中二', 0.012415877149935613),
#  ('男人', 0.01119768763623508),
#  ('每天', 0.010677188461427619),
#  ('搭配', 0.008405667287254708),
#  ('点击', 0.008330767791507354),
#  ('穿衣', 0.008223824307558074),
#  ('轻松', 0.00784242767545962),
#  ('排毒', 0.00757083651006539),
#  ('添加', 0.007232440517723846),
#  ('先点', 0.007181329530679199)]
# '************************************************************'
# Most 20 Important words in TOPIC 17 :
#
# [('长征', 0.04563797755307529),
#  ('红军', 0.036410805553235025),
#  ('军长', 0.016123150158983218),
#  ('胜利', 0.014315954853729534),
#  ('长征路', 0.011271313072013438),
#  ('革命', 0.011244219944875193),
#  ('精神', 0.01089003424610501),
#  ('共产', 0.01046548067751872),
#  ('伟大', 0.009511425705732357),
#  ('共产党', 0.009508324216060526),
#  ('纪念', 0.009152014276137944),
#  ('民族', 0.007890246078819538),
#  ('毛泽东', 0.0071908912381891885),
#  ('周年', 0.007061258951856416),
#  ('中国共产党', 0.006737541889559213),
#  ('国共', 0.006615720700201161),
#  ('方面军', 0.006501298603243904),
#  ('战士', 0.006500008235604631),
#  ('草地', 0.006014142479162288),
#  ('部队', 0.005836134707750584)]
# '************************************************************'
# Most 20 Important words in TOPIC 18 :
#
# [('旅游', 0.06317596491926042),
#  ('景区', 0.025226253806750875),
#  ('游客', 0.020159161003029415),
#  ('旅游局', 0.01765341363575593),
#  ('旅行社', 0.014080388997739786),
#  ('行社', 0.013222088371769036),
#  ('旅行', 0.012573103965614757),
#  ('不文', 0.011182349671397418),
#  ('国家旅游局', 0.01024761720666323),
#  ('文明', 0.010149844747227776),
#  ('导游', 0.009914747306694277),
#  ('游业', 0.00806428450900532),
#  ('旅游业', 0.008043707489305269),
#  ('乡村', 0.007379803349417023),
#  ('国旅', 0.007183989626939075),
#  ('旅游者', 0.006995521529324157),
#  ('目的地', 0.006768677933825792),
#  ('游者', 0.006719551647587816),
#  ('携程', 0.006388715728375867),
#  ('景点', 0.005595510569655475)]
# '************************************************************'
# Most 20 Important words in TOPIC 19 :
#
# [('纳税', 0.03351648779100446),
#  ('税收', 0.029006459729371308),
#  ('税务', 0.02824965411945311),
#  ('收入', 0.02477000088509965),
#  ('所得', 0.023019762326849852),
#  ('纳税人', 0.022679947363447566),
#  ('个税', 0.018053043139380723),
#  ('增值税', 0.014295004551540617),
#  ('国税', 0.014283131543383468),
#  ('所得税', 0.01413634482553714),
#  ('发票', 0.012856527559988984),
#  ('收入者', 0.01275291520722825),
#  ('申报', 0.011686059067087383),
#  ('税负', 0.011608498076985493),
#  ('税改', 0.011325180920036804),
#  ('增值', 0.011172135023340921),
#  ('地税', 0.011059945872451005),
#  ('税务机关', 0.010707908679163098),
#  ('税务总局', 0.01069091142076199),
#  ('个人所得', 0.009855191020352167)]
# '************************************************************'
# Most 20 Important words in TOPIC 20 :
#
# [('游戏', 0.04841348039923061),
#  ('玩家', 0.03414089428688768),
#  ('英雄', 0.008586730570044785),
#  ('玩法', 0.008287492266279194),
#  ('技能', 0.006970801720260514),
#  ('装备', 0.006887580664940868),
#  ('任天堂', 0.006737656183761499),
#  ('天堂', 0.005409690777624077),
#  ('体验', 0.0052343870125167846),
#  ('战斗', 0.0050541570264731025),
#  ('移动游戏', 0.0048469677322010045),
#  ('版本', 0.0048368110204891155),
#  ('让玩家', 0.004787812700564632),
#  ('显卡', 0.004781495779154725),
#  ('一款', 0.004535336694522095),
#  ('伤害', 0.004346891619222055),
#  ('三国', 0.004277539928967857),
#  ('移动', 0.0040383238448107655),
#  ('这款', 0.003990107893725278),
#  ('角色', 0.003867114802626994)]
# '************************************************************'
# Most 20 Important words in TOPIC 21 :
#
# [('搭配', 0.026006313955085063),
#  ('时尚', 0.01727621169393933),
#  ('牛仔', 0.01588396929507591),
#  ('外套', 0.014834239991487915),
#  ('毛衣', 0.013546459622048592),
#  ('针织', 0.012844910223100579),
#  ('衬衫', 0.011220439196802191),
#  ('大衣', 0.009962134975869933),
#  ('版型', 0.009779955417122605),
#  ('条纹', 0.009674983484154498),
#  ('面料', 0.009306626976080314),
#  ('款式', 0.009177233124882786),
#  ('宽松', 0.008890183374839275),
#  ('时髦', 0.008614603035157455),
#  ('衣裙', 0.008483121351709698),
#  ('黑色', 0.008286693467534693),
#  ('秋冬', 0.008095834862889213),
#  ('连衣', 0.007962584033852943),
#  ('牛仔裤', 0.007933415573131417),
#  ('优雅', 0.007836962474864708)]
# '************************************************************'
# Most 20 Important words in TOPIC 22 :
#
# [('癌症', 0.03154859225792204),
#  ('肿瘤', 0.026885907727434565),
#  ('疫苗', 0.02569580432728052),
#  ('腺癌', 0.021382919654736265),
#  ('治疗', 0.020962459322048897),
#  ('乳腺', 0.02095763414639851),
#  ('细胞', 0.01937297601722987),
#  ('患者', 0.017738416559106376),
#  ('宫颈', 0.016903648848853595),
#  ('肠癌', 0.01655976814057007),
#  ('宫颈癌', 0.016337678838311),
#  ('乳腺癌', 0.015951475753424604),
#  ('肝癌', 0.014949237909847809),
#  ('胃癌', 0.013347636043193589),
#  ('化疗', 0.011645832953641223),
#  ('临床', 0.009872342900190519),
#  ('预防', 0.009666113130054216),
#  ('致癌', 0.009229187562271625),
#  ('发病', 0.008664964577019565),
#  ('免疫', 0.008524269347692175)]
# '************************************************************'
# Most 20 Important words in TOPIC 23 :
#
# [('肌肤', 0.03101383483608523),
#  ('皮肤', 0.02815655195795336),
#  ('化妆', 0.012826537843665239),
#  ('面部', 0.01133316970754671),
#  ('保湿', 0.011222128768331799),
#  ('护肤', 0.011208261225094765),
#  ('眼睛', 0.010879364091495971),
#  ('脸部', 0.010519058837157697),
#  ('化妆水', 0.010156886245976708),
#  ('眼部', 0.009643446720531603),
#  ('眼皮', 0.009632817171041155),
#  ('手术', 0.008779497949584353),
#  ('面膜', 0.00877205908545021),
#  ('精华', 0.008026192328566743),
#  ('色素', 0.00798768629660245),
#  ('祛斑', 0.007914137011954741),
#  ('毛孔', 0.007862509214830848),
#  ('眼线', 0.007752889368463512),
#  ('色斑', 0.007588494745472868),
#  ('双眼', 0.007484750518867396)]
# '************************************************************'
# Most 20 Important words in TOPIC 24 :
#
# [('考试', 0.007902342610431948),
#  ('学生', 0.006955311795360358),
#  ('教育', 0.006650132859256686),
#  ('考生', 0.006622958746999335),
#  ('学校', 0.00636044085447386),
#  ('家长', 0.005339795449739366),
#  ('教师', 0.005324943015225707),
#  ('学习', 0.004971131888210113),
#  ('大学', 0.004880576042736733),
#  ('招生', 0.004650154029168649),
#  ('老师', 0.004592006879542813),
#  ('孩子', 0.0044060314127661055),
#  ('报名', 0.0043607688839811904),
#  ('教学', 0.0042728196202593705),
#  ('高考', 0.004144811025607766),
#  ('英语', 0.004104036170055219),
#  ('小学', 0.004058143606715937),
#  ('成绩', 0.0040178729520920446),
#  ('留学', 0.0040091366797526595),
#  ('报考', 0.004002858493977206)]
# '************************************************************'
# Most 20 Important words in TOPIC 25 :
#
# [('机器人', 0.06672466739797703),
#  ('机器', 0.06666620490668082),
#  ('人工智能', 0.026401995072502155),
#  ('人工', 0.022391862007660888),
#  ('智能', 0.0208267564413823),
#  ('无人机', 0.01997902250114014),
#  ('人机', 0.019751214543844858),
#  ('无人', 0.018157485669332767),
#  ('工业', 0.00840327918790011),
#  ('视觉', 0.007432766691386001),
#  ('应用', 0.0068945718567455915),
#  ('人类', 0.006716749964290903),
#  ('领域', 0.006483976644822228),
#  ('制造', 0.006383616410136899),
#  ('自动化', 0.006226992177564663),
#  ('自动', 0.005801396236447931),
#  ('智能机', 0.005201417590889969),
#  ('技术', 0.005135145403560498),
#  ('科技', 0.00434745432522162),
#  ('学习', 0.004150225357250975)]
# '************************************************************'
# Most 20 Important words in TOPIC 26 :
#
# [('希拉里', 0.06577962519080895),
#  ('希拉', 0.06546845150593114),
#  ('拉里', 0.06374839327048812),
#  ('特朗普', 0.04979027821416807),
#  ('总统', 0.031287874860965334),
#  ('共和党', 0.02663588321616248),
#  ('克林顿', 0.021448911900291488),
#  ('民主党', 0.019721897227713565),
#  ('民主', 0.018832810567727908),
#  ('选人', 0.01845328771767675),
#  ('候选人', 0.01836029443610924),
#  ('大选', 0.01826306100909475),
#  ('共和', 0.0182315413620617),
#  ('竞选', 0.01817090120713176),
#  ('候选', 0.01754177603574673),
#  ('辩论', 0.01637132020441576),
#  ('美国', 0.01595179146077087),
#  ('奥巴马', 0.014333034832763198),
#  ('奥巴', 0.014218811933446613),
#  ('巴马', 0.013979546690596244)]
# '************************************************************'
# Most 20 Important words in TOPIC 27 :
#
# [('手机', 0.027784741666612486),
#  ('三星', 0.020895506187843485),
#  ('小米', 0.017460408724934803),
#  ('华为', 0.011018719315166615),
#  ('摄像', 0.009201193287581105),
#  ('像素', 0.008906980453243264),
#  ('像头', 0.008893742042788866),
#  ('摄像头', 0.008889752270349674),
#  ('理器', 0.008631768842499844),
#  ('处理器', 0.00860629280891685),
#  ('电池', 0.007953808757723063),
#  ('智能手机', 0.007665591155247993),
#  ('能手', 0.007401769182866888),
#  ('屏幕', 0.007302809643368592),
#  ('机身', 0.0071413462733700105),
#  ('智能', 0.0069034045981970936),
#  ('用户', 0.006424860390260831),
#  ('充电', 0.006157823430646222),
#  ('采用', 0.005766752800743607),
#  ('内存', 0.005717312573974626)]
# '************************************************************'
# Most 20 Important words in TOPIC 28 :
#
# [('苹果', 0.07223933236331835),
#  ('苹果公司', 0.016027403942221775),
#  ('手表', 0.010217519986033364),
#  ('乔布', 0.009207365873463607),
#  ('乔布斯', 0.009207365873463607),
#  ('布斯', 0.00824258247150454),
#  ('手机', 0.007308019174698066),
#  ('英寸', 0.007105036702180068),
#  ('用户', 0.007063189865686308),
#  ('屏幕', 0.006894160302753089),
#  ('库克', 0.006282638425871421),
#  ('以旧换新', 0.005904691672128745),
#  ('设备', 0.0059026863593772665),
#  ('能手', 0.0058283247607338684),
#  ('键盘', 0.0057798932790425195),
#  ('推出', 0.005714967513915819),
#  ('发布', 0.005666856581154357),
#  ('富士康', 0.005537120293360812),
#  ('换新', 0.005356279998320032),
#  ('果在', 0.0053171483932647045)]
# '************************************************************'
# Most 20 Important words in TOPIC 29 :
#
# [('螃蟹', 0.035127157685029546),
#  ('钓鱼', 0.0275922594645093),
#  ('饵料', 0.021688412365858358),
#  ('大闸蟹', 0.018452648204873585),
#  ('大闸', 0.018380162177988733),
#  ('鲫鱼', 0.016298114175857435),
#  ('龙虾', 0.013461102623264559),
#  ('垂钓', 0.012180688828854253),
#  ('蟹黄', 0.011203045293682557),
#  ('小龙虾', 0.01019979045753374),
#  ('水产', 0.008726024641575804),
#  ('大鱼', 0.008703178584980117),
#  ('养殖', 0.008582073252295864),
#  ('潜水', 0.008266919591351828),
#  ('小龙', 0.008190999352238475),
#  ('河蟹', 0.008010920659330872),
#  ('海鲜', 0.007888160534843208),
#  ('磷虾', 0.007186286431290964),
#  ('阳澄湖', 0.007179484985315577),
#  ('渔业', 0.0070950131921461755)]
# '************************************************************'
# Most 20 Important words in TOPIC 30 :
#
# [('气温', 0.015765743772660545),
#  ('气象', 0.015484861132539517),
#  ('天气', 0.01518757986575201),
#  ('台风', 0.013546793635857358),
#  ('暴雨', 0.013354977814069809),
#  ('降雨', 0.012031937916272209),
#  ('供热', 0.00845391718317541),
#  ('气象台', 0.007965630457822465),
#  ('降水', 0.007781526372500694),
#  ('高温', 0.007205504083306814),
#  ('北部', 0.007017843689968349),
#  ('地区', 0.006943590500262016),
#  ('冷空气', 0.006935493223661709),
#  ('多云', 0.006837723731045406),
#  ('预警', 0.00663307682433913),
#  ('毫米', 0.006604102361379039),
#  ('南部', 0.00653025731283896),
#  ('高气', 0.006098070852949262),
#  ('预报', 0.006091312842292324),
#  ('空气', 0.005806022468103133)]
# '************************************************************'
# Most 20 Important words in TOPIC 31 :
#
# [('宝宝', 0.026837457043524464),
#  ('孕妇', 0.021175153069632083),
#  ('胎儿', 0.019935854953786133),
#  ('怀孕', 0.019668086936311738),
#  ('孕期', 0.01584119380509836),
#  ('子宫', 0.014620813188280112),
#  ('妈妈', 0.014382215261184826),
#  ('妊娠', 0.01222095131793275),
#  ('分娩', 0.011803698329452375),
#  ('准妈妈', 0.011711715200358965),
#  ('产后', 0.010996506293397977),
#  ('胎盘', 0.010438306328890694),
#  ('发育', 0.009876745845507085),
#  ('排卵', 0.00891580188988696),
#  ('女性', 0.008700025023558438),
#  ('辐射', 0.00792225146495163),
#  ('婴儿', 0.00761434262336563),
#  ('产妇', 0.007469670358825734),
#  ('食物', 0.00745401174006123),
#  ('激素', 0.007363288538109559)]
# '************************************************************'
# Most 20 Important words in TOPIC 32 :
#
# [('航天', 0.0703806778674499),
#  ('航天员', 0.05248731738701505),
#  ('神舟', 0.032664135194584644),
#  ('太空', 0.032518561425931236),
#  ('天宫', 0.02903967023763257),
#  ('飞船', 0.028827606631041624),
#  ('十一号', 0.02695807003439947),
#  ('二号', 0.02650514347306875),
#  ('一号', 0.025489744640366106),
#  ('发射', 0.024748378229908486),
#  ('飞行', 0.023185638779414427),
#  ('载人', 0.022451425102363528),
#  ('景海鹏', 0.020130519510830298),
#  ('十一', 0.01935975919806739),
#  ('卫星', 0.01578911906973033),
#  ('任务', 0.014821458113889605),
#  ('国航', 0.01227792283701517),
#  ('空间站', 0.012216920853263974),
#  ('对接', 0.01168811629704445),
#  ('中国航天', 0.01122071455812269)]
# '************************************************************'
# Most 20 Important words in TOPIC 33 :
#
# [('关节', 0.015242382213270624),
#  ('治疗', 0.014309009420005644),
#  ('疼痛', 0.013608481923135773),
#  ('患者', 0.013441547621402657),
#  ('症状', 0.011689686985869717),
#  ('血管', 0.011514775448934115),
#  ('神经', 0.011264480452608732),
#  ('疾病', 0.009953706017224492),
#  ('骨质', 0.009345998230605354),
#  ('颈椎', 0.008614068171470464),
#  ('咽炎', 0.008193527390564479),
#  ('结石', 0.007701597665938997),
#  ('慢性', 0.007630933228055493),
#  ('血压', 0.007207158163977695),
#  ('关节炎', 0.006998754097161446),
#  ('疏松', 0.006776454848910587),
#  ('三叉神经', 0.006615737786455938),
#  ('食物', 0.006534382025637671),
#  ('病人', 0.0064660152590082605),
#  ('引起', 0.006210516465408798)]
# '************************************************************'
# Most 20 Important words in TOPIC 34 :
#
# [('放入', 0.03239210896324553),
#  ('倒入', 0.021804175904089174),
#  ('适量', 0.02063590339557941),
#  ('鸡蛋', 0.02046004925034411),
#  ('翻炒', 0.015898500751996322),
#  ('少许', 0.01582321012571832),
#  ('加入', 0.015450761070795764),
#  ('辣椒', 0.014838327264127179),
#  ('做法', 0.014166216909926874),
#  ('均匀', 0.01325233029615767),
#  ('小火', 0.012647820163426362),
#  ('豆腐', 0.012596180584653546),
#  ('切成', 0.012522042161075829),
#  ('分钟', 0.012513945908797446),
#  ('料酒', 0.012251524285183004),
#  ('生抽', 0.012085817359741633),
#  ('洗净', 0.012020039015685316),
#  ('即可', 0.011501519849341956),
#  ('搅拌', 0.011493046024353672),
#  ('胡椒', 0.011125797788329927)]
# '************************************************************'
# Most 20 Important words in TOPIC 35 :
#
# [('维生素', 0.020142341099318336),
#  ('维生', 0.020069259076621736),
#  ('营养', 0.01760646276462454),
#  ('含有', 0.01758179592413707),
#  ('水果', 0.013969171158906448),
#  ('食用', 0.01231904021842712),
#  ('食物', 0.011890729839299147),
#  ('蛋白', 0.010830313920016925),
#  ('香蕉', 0.010560871065194667),
#  ('作用', 0.010489167038560426),
#  ('功效', 0.010488298279166131),
#  ('萝卜', 0.010070374643021738),
#  ('物质', 0.009967772619740429),
#  ('含量', 0.009762923038034433),
#  ('人体', 0.009567942064310015),
#  ('富含', 0.009228769904653536),
#  ('蛋白质', 0.00922367415626481),
#  ('白质', 0.009198521503736673),
#  ('枸杞', 0.00919465188601822),
#  ('脂肪', 0.008896196304391672)]
# '************************************************************'
# Most 20 Important words in TOPIC 36 :
#
# [('健身', 0.03695662833868194),
#  ('跑步', 0.03469754786002697),
#  ('肌肉', 0.021593537399545712),
#  ('训练', 0.021088632576222358),
#  ('动作', 0.02044643313623739),
#  ('运动', 0.019505605547226624),
#  ('锻炼', 0.01566166503776469),
#  ('身体', 0.014740292462272365),
#  ('减肥', 0.013147364216273248),
#  ('跑步机', 0.010594524372150827),
#  ('体重', 0.009590134814236458),
#  ('脂肪', 0.009208840453282335),
#  ('有氧', 0.008813661439423848),
#  ('俯卧', 0.008739889829381823),
#  ('哑铃', 0.008689045322672416),
#  ('俯卧撑', 0.008582586769926336),
#  ('健身房', 0.008452990805504726),
#  ('蛋白', 0.007822138708268155),
#  ('关节', 0.007750476955524005),
#  ('教练', 0.007381989164301289)]
# '************************************************************'
# Most 20 Important words in TOPIC 37 :
#
# [('电影', 0.009123607971680278),
#  ('导演', 0.006695709645045901),
#  ('节目', 0.0065977760072051935),
#  ('演员', 0.006315771756510618),
#  ('观众', 0.006253511255958489),
#  ('歌手', 0.0048327414838248185),
#  ('网友', 0.0047093170806211185),
#  ('主演', 0.0041497668111723255),
#  ('影片', 0.004081819559795581),
#  ('明星', 0.00400884675635393),
#  ('音乐', 0.003975924825574597),
#  ('娱乐', 0.003929100116599844),
#  ('饰演', 0.0038704123510004923),
#  ('粉丝', 0.003606024047432892),
#  ('电视', 0.0034885777859544535),
#  ('角色', 0.0034623359134266147),
#  ('拍摄', 0.0034502582268510907),
#  ('电视剧', 0.0033878017130019498),
#  ('卫视', 0.0032656332095534774),
#  ('婚礼', 0.0031486515221233443)]
# '************************************************************'
# Most 20 Important words in TOPIC 38 :
#
# [('男人', 0.0034629069492823797),
#  ('女人', 0.00304899114673965),
#  ('人生', 0.002460518403474777),
#  ('爱情', 0.0021725016078857034),
#  ('喜欢', 0.0021210750248616796),
#  ('文化', 0.001866076231635851),
#  ('旅游', 0.001850213169906149),
#  ('生活', 0.0018466591319529538),
#  ('景区', 0.001823950635331619),
#  ('公园', 0.0017656550305885622),
#  ('婚姻', 0.0017591285345177697),
#  ('感情', 0.0017456318161347766),
#  ('艺术', 0.001737749064980937),
#  ('朋友', 0.0017261508324804586),
#  ('知道', 0.0016619975546412688),
#  ('风景', 0.0016416875138991946),
#  ('幸福', 0.0016017339843925164),
#  ('一种', 0.0016006185907616606),
#  ('个人', 0.0016002353453806626),
#  ('不要', 0.0015850780550567649)]
# '************************************************************'
# Most 20 Important words in TOPIC 39 :
#
# [('员工', 0.02893230737474878),
#  ('老板', 0.012216547783767255),
#  ('职场', 0.011594792373708728),
#  ('上司', 0.010550965852999769),
#  ('沟通', 0.009576251801104132),
#  ('抱怨', 0.00693788558980147),
#  ('领导', 0.006008146203132912),
#  ('下属', 0.0058983794513610965),
#  ('团队', 0.005888375413706656),
#  ('加薪', 0.005651794184507777),
#  ('管理者', 0.005198333306212495),
#  ('美容', 0.004837582697360244),
#  ('同事', 0.004728577889371679),
#  ('情绪', 0.004524925237896291),
#  ('批评', 0.0044591262775077025),
#  ('排斥', 0.0043318893640214825),
#  ('事情', 0.004118666995535955),
#  ('能力', 0.004057035477295237),
#  ('美容院', 0.003770310680060908),
#  ('客户', 0.003696343022240535)]
# '************************************************************'
# Most 20 Important words in TOPIC 40 :
#
# [('原油', 0.038046212109209415),
#  ('油价', 0.030465741874617168),
#  ('石油', 0.01911680127698545),
#  ('万桶', 0.017394449528875214),
#  ('库存', 0.016071644243878875),
#  ('天然气', 0.015817566621597945),
#  ('油库', 0.015602176499526886),
#  ('止损', 0.013448499180161581),
#  ('美元', 0.01344790430410626),
#  ('行情', 0.012595951949572652),
#  ('天然', 0.01255168675151955),
#  ('产量', 0.011157117914687159),
#  ('油价格', 0.010309489994951194),
#  ('附近', 0.0101818815881529),
#  ('减产', 0.009932866373230074),
#  ('操作', 0.009311720222065868),
#  ('反弹', 0.008444701938166061),
#  ('支撑', 0.008210261598733408),
#  ('均线', 0.007817278443937719),
#  ('产油', 0.007692440470823984)]
# '************************************************************'
# Most 20 Important words in TOPIC 41 :
#
# [('展会', 0.007359988883276197),
#  ('参展', 0.006240780834297266),
#  ('创新', 0.00618414435724),
#  ('展览', 0.005579413215208943),
#  ('产业', 0.005119971499519817),
#  ('国际', 0.005024784880368386),
#  ('创业', 0.0050050184397025365),
#  ('峰会', 0.0048811662336516),
#  ('科技', 0.00481616458608946),
#  ('深圳', 0.004706403469546246),
#  ('联网', 0.004684792683124171),
#  ('论坛', 0.004623396621247612),
#  ('博览', 0.004535375614816399),
#  ('互联', 0.004384036829189732),
#  ('全球', 0.004278815584700779),
#  ('互联网', 0.004194694582098659),
#  ('行业', 0.004063577895514926),
#  ('展位', 0.004060005662097418),
#  ('博会', 0.003973503505343921),
#  ('大会', 0.003928367540838488)]
# '************************************************************'
# Most 20 Important words in TOPIC 42 :
#
# [('网站', 0.017165559461677974),
#  ('关键词', 0.01268559799418276),
#  ('索引', 0.01108616570213864),
#  ('搜索引擎', 0.010794838564448501),
#  ('营销', 0.00935608176177356),
#  ('搜索', 0.009241791417094828),
#  ('用户', 0.009052024205895397),
#  ('引擎', 0.008753458611402518),
#  ('关键', 0.007964698476926935),
#  ('页面', 0.007767109194695654),
#  ('优化', 0.007316871664620993),
#  ('广告', 0.006838052778726857),
#  ('网页', 0.0067368121224149575),
#  ('内容', 0.006565476435196333),
#  ('媒体', 0.005138026342526535),
#  ('文章', 0.004821546179318035),
#  ('新闻', 0.004817541181191296),
#  ('平台', 0.004713951517400259),
#  ('排名', 0.004682026592674249),
#  ('小程', 0.004640427627914058)]
# '************************************************************'
# Most 20 Important words in TOPIC 43 :
#
# [('互联网', 0.011494774108708396),
#  ('互联', 0.011366169402006212),
#  ('联网', 0.011346159929072291),
#  ('阿里', 0.008431104988604176),
#  ('电商', 0.007883545109228462),
#  ('用户', 0.007271504589064539),
#  ('营销', 0.00598908669078796),
#  ('数据', 0.005445322302539164),
#  ('大数', 0.005120190465517773),
#  ('物流', 0.004940504888975684),
#  ('平台', 0.004660737857776456),
#  ('移动', 0.00445179956540425),
#  ('消费', 0.004433000555866448),
#  ('阿里巴巴', 0.004303740763679063),
#  ('网络', 0.00429006161528474),
#  ('模式', 0.0042483075712289944),
#  ('传统', 0.004236176405224212),
#  ('运营', 0.004205026511153598),
#  ('线下', 0.0040671364604547),
#  ('流量', 0.003912177577616226)]
# '************************************************************'
# Most 20 Important words in TOPIC 44 :
#
# [('房价', 0.017973171437667343),
#  ('地产', 0.016364318047023645),
#  ('房地', 0.015046264095074095),
#  ('房地产', 0.015041351246239976),
#  ('住房', 0.014932115038633715),
#  ('购房', 0.012161422443253557),
#  ('楼市', 0.01098090777617582),
#  ('住宅', 0.009812157950834904),
#  ('新政', 0.009068780470833617),
#  ('积金', 0.008932688185184355),
#  ('公积金', 0.008930962501616147),
#  ('公积', 0.008762738858850719),
#  ('成交', 0.008728560186329616),
#  ('首付', 0.008482950215881373),
#  ('城市', 0.00807788112701297),
#  ('贷款', 0.007506276817384244),
#  ('套房', 0.007462439376967311),
#  ('平方米', 0.007373560163943696),
#  ('二手房', 0.007354191213788643),
#  ('平方', 0.00711446696790747)]
# '************************************************************'
# Most 20 Important words in TOPIC 45 :
#
# [('经济', 0.00930943961527233),
#  ('增长', 0.006445849087782357),
#  ('财富', 0.004824889257018125),
#  ('崩溃', 0.0046115649025161255),
#  ('美国', 0.004195246653457011),
#  ('全球', 0.004173102883715359),
#  ('危机', 0.003960533229182518),
#  ('国人', 0.0038977894483006727),
#  ('日本', 0.0038603070452797993),
#  ('美元', 0.003687881465127888),
#  ('洗牌', 0.003623846911622912),
#  ('消费', 0.00352144566242404),
#  ('制造', 0.0035068673588985787),
#  ('改革', 0.0034486297265243554),
#  ('增速', 0.003377056494766556),
#  ('人口', 0.0033382219340745245),
#  ('产业', 0.00326777361851899),
#  ('经济体', 0.0032094898865528687),
#  ('房地产', 0.0031430877092574706),
#  ('房地', 0.003128561236592525)]
# '************************************************************'
# Most 20 Important words in TOPIC 46 :
#
# [('同比', 0.02581279472350897),
#  ('净利', 0.022391161999908746),
#  ('净利润', 0.02108468441304787),
#  ('比增', 0.019642526489798185),
#  ('利润', 0.019220607144836196),
#  ('亿元', 0.016051012477432066),
#  ('季度', 0.01602776718567826),
#  ('增长', 0.014617394882703836),
#  ('业绩', 0.013975747029385904),
#  ('三季', 0.013107384449209872),
#  ('营业', 0.012605102923203436),
#  ('收入', 0.011429607630231223),
#  ('三季度', 0.01129553560312355),
#  ('每股', 0.010823692271058777),
#  ('同期', 0.010350330385613032),
#  ('亏损', 0.009122514974005595),
#  ('归属', 0.009023283671442827),
#  ('归属于', 0.00890653109553921),
#  ('实现', 0.008849194437001998),
#  ('下降', 0.008810068846398756)]
# '************************************************************'
# Most 20 Important words in TOPIC 47 :
#
# [('防水', 0.008583981952310133),
#  ('污水', 0.00847003540414037),
#  ('农业', 0.007936458967902838),
#  ('建设', 0.007861559302345328),
#  ('农村', 0.007323083312646045),
#  ('生态', 0.006911088496431889),
#  ('农民', 0.006901317765777153),
#  ('污染', 0.006468474270366888),
#  ('污水处理', 0.00639120719795949),
#  ('改造', 0.006323173626806775),
#  ('城市', 0.006119040508983468),
#  ('示范区', 0.005759668276172494),
#  ('示范', 0.005741593452943381),
#  ('城镇', 0.005686256198274363),
#  ('环境', 0.005473062350925617),
#  ('城市群', 0.005459024758312281),
#  ('工程', 0.0054388572256975016),
#  ('水利', 0.005247552322131534),
#  ('防水材料', 0.005191594568216413),
#  ('产业', 0.004815173819621874)]
# '************************************************************'
# Most 20 Important words in TOPIC 48 :
#
# [('书记', 0.006803460206359115),
#  ('政治', 0.005794758268926158),
#  ('领导', 0.0055295111623685665),
#  ('中央', 0.0054087696183883075),
#  ('朝鲜', 0.005388886653706215),
#  ('干部', 0.005215753514165889),
#  ('党员', 0.005156544807225343),
#  ('会议', 0.004978628896321775),
#  ('建设', 0.004740341813265937),
#  ('常委', 0.004662774761618936),
#  ('菲律宾', 0.004498514325623087),
#  ('党组', 0.0044918345176988735),
#  ('习近平', 0.004399839316070059),
#  ('落实', 0.004382242304448271),
#  ('治党', 0.004217661901715551),
#  ('委员', 0.004089049969764444),
#  ('党内', 0.0040089419904981785),
#  ('韩国', 0.003964654652288053),
#  ('全面', 0.003940315164467047),
#  ('从严', 0.0038923992394979405)]
# '************************************************************'
# Most 20 Important words in TOPIC 49 :
#
# [('航空', 0.042891244252650014),
#  ('机场', 0.033970058148627316),
#  ('飞机', 0.03212839522563954),
#  ('航班', 0.031502551021989775),
#  ('航线', 0.02343578750451846),
#  ('航空公司', 0.022210058644472258),
#  ('飞行', 0.02026959070064938),
#  ('民航', 0.017628450740392657),
#  ('跑道', 0.017162859283336974),
#  ('旅客', 0.01669301887353488),
#  ('起飞', 0.013599754445586178),
#  ('延误', 0.010993153884732347),
#  ('南航', 0.008693437983285576),
#  ('客机', 0.008468958127311672),
#  ('民航局', 0.008453235259872037),
#  ('东航', 0.008415783226821943),
#  ('乘客', 0.008145085717169449),
#  ('空管', 0.007528291611859086),
#  ('一架', 0.0068695179970655095),
#  ('塔台', 0.006569082045666527)]
# '************************************************************'
# Most 20 Important words in TOPIC 50 :
#
# [('也门', 0.0595162952009088),
#  ('武装', 0.05193298367256751),
#  ('沙特', 0.037322424541364106),
#  ('伊拉克', 0.03017568985962224),
#  ('伊拉', 0.03005275320003846),
#  ('拉克', 0.027106300313779096),
#  ('空袭', 0.026383761859582428),
#  ('叙利亚', 0.022645764621896804),
#  ('伊朗', 0.021600588031730476),
#  ('伊斯兰', 0.021209624425577448),
#  ('阿拉伯', 0.019629790590753742),
#  ('拉伯', 0.019571316630128597),
#  ('伊斯', 0.018669786626595585),
#  ('阿拉', 0.017117548016304582),
#  ('袭击', 0.01705662791870764),
#  ('亚丁', 0.016839201142694403),
#  ('什叶派', 0.01528725158182016),
#  ('什叶', 0.015234389898256746),
#  ('总统', 0.014959011035381465),
#  ('利亚', 0.01392877251736103)]
# '************************************************************'
# Most 20 Important words in TOPIC 51 :
#
# [('潜艇', 0.02026015831825542),
#  ('导弹', 0.019705153311519896),
#  ('海军', 0.019624733442451706),
#  ('俄罗斯', 0.019253648225903443),
#  ('罗斯', 0.018597973145394027),
#  ('航母', 0.016413364326975786),
#  ('战斗', 0.013388320280577178),
#  ('军事', 0.011486840073713585),
#  ('空军', 0.011435166100326874),
#  ('武器', 0.011182034596506345),
#  ('战斗机', 0.010585171236338429),
#  ('演习', 0.010360730471538668),
#  ('国海军', 0.009918286802421364),
#  ('战机', 0.009320916145197752),
#  ('国防', 0.008639338584226885),
#  ('作战', 0.008076602193273132),
#  ('美军', 0.00788702927788538),
#  ('驱逐舰', 0.0073059394281688),
#  ('普京', 0.007178166847987),
#  ('海上', 0.007014927417653535)]
# '************************************************************'
# Most 20 Important words in TOPIC 52 :
#
# [('联储', 0.0212249749797933),
#  ('美元', 0.020622962291828688),
#  ('美联储', 0.019265092444661035),
#  ('黄金', 0.018997223796856946),
#  ('加息', 0.015913471426506655),
#  ('人民币', 0.015202784819817584),
#  ('汇率', 0.013405922389678757),
#  ('贬值', 0.012858219094842117),
#  ('欧元', 0.012427611534707344),
#  ('金价', 0.012235484111229784),
#  ('央行', 0.011521852011813405),
#  ('货币', 0.010352967386123697),
#  ('预期', 0.010349276689475887),
#  ('白银', 0.009500410391808612),
#  ('人民', 0.008835944388048597),
#  ('英镑', 0.007994681805687937),
#  ('指数', 0.007602836180027054),
#  ('盎司', 0.007548847925568461),
#  ('现货', 0.007342372137826196),
#  ('支撑', 0.007273453817536594)]
# '************************************************************'
# Most 20 Important words in TOPIC 53 :
#
# [('消防', 0.04984451254590427),
#  ('火灾', 0.021925854467756075),
#  ('爆炸', 0.01862111247770127),
#  ('起火', 0.016397299892826026),
#  ('灭火', 0.013980052153941354),
#  ('救援', 0.012478669026268882),
#  ('官兵', 0.012447722771118377),
#  ('防火', 0.011201719150026294),
#  ('事故', 0.011003511138633659),
#  ('火势', 0.010841831353308658),
#  ('消防官兵', 0.010775158148727267),
#  ('现场', 0.00996949152140808),
#  ('被困', 0.009707649547351049),
#  ('消防安全', 0.008967155828205984),
#  ('扑灭', 0.008955707747098026),
#  ('着火', 0.008714171121786267),
#  ('大火', 0.008479140159907349),
#  ('面粉', 0.008102799872069025),
#  ('发生', 0.007840762718876567),
#  ('消防员', 0.007479500955159475)]
# '************************************************************'
# Most 20 Important words in TOPIC 54 :
#
# [('个股', 0.008665757219400879),
#  ('大盘', 0.008290534097389632),
#  ('股市', 0.007896780220589593),
#  ('行情', 0.007729514637667982),
#  ('投资者', 0.007625478415013845),
#  ('股票', 0.007435154842360879),
#  ('板块', 0.007219036633770822),
#  ('涨停', 0.006929027909635186),
#  ('上涨', 0.006561993907696608),
#  ('震荡', 0.0064320378723607035),
#  ('股价', 0.0063982602625474155),
#  ('指数', 0.00627025338388324),
#  ('涨幅', 0.005819407407864534),
#  ('创业板', 0.005727106720485249),
#  ('资金', 0.005662896442455079),
#  ('成交', 0.005444949426629484),
#  ('操作', 0.005399911900687964),
#  ('走势', 0.00503303000243423),
#  ('均线', 0.005021728564558337),
#  ('趋势', 0.004965894048132765)]
# '************************************************************'
# Most 20 Important words in TOPIC 55 :
#
# [('发行', 0.01090618155140865),
#  ('证券', 0.010820772042031466),
#  ('申购', 0.008716992810688592),
#  ('份额', 0.008501456146792876),
#  ('股权', 0.007779786496747262),
#  ('股东', 0.007757194890870173),
#  ('基金', 0.007744983261205823),
#  ('资产', 0.007263315759168126),
#  ('股份', 0.006956544179536613),
#  ('私募', 0.0068241442821451075),
#  ('股票', 0.00640797202805206),
#  ('持有', 0.006214373691812704),
#  ('转让', 0.006019342876710308),
#  ('投资者', 0.005608567983069231),
#  ('公告', 0.005512982369725599),
#  ('上市', 0.005484244861309482),
#  ('赎回', 0.005409341836067143),
#  ('债券', 0.005026242738346189),
#  ('募集', 0.005019856103975077),
#  ('交易', 0.004975214847668173)]
# '************************************************************'
# Most 20 Important words in TOPIC 56 :
#
# [('犯罪', 0.011960551868224647),
#  ('法院', 0.011931968011617179),
#  ('案件', 0.010187168511799493),
#  ('嫌疑', 0.010179986146565845),
#  ('嫌疑人', 0.01015242038060085),
#  ('检察', 0.009467712826067294),
#  ('民警', 0.009428707984909513),
#  ('警方', 0.009061679524930694),
#  ('公安', 0.008175705832506512),
#  ('罪嫌', 0.006974997549439778),
#  ('被告', 0.006861438935905441),
#  ('抓获', 0.006077868779471901),
#  ('盗窃', 0.005852250432193025),
#  ('检察院', 0.005774761289302403),
#  ('察院', 0.0057677390458986295),
#  ('被告人', 0.005736269271193023),
#  ('受贿', 0.005631514533799334),
#  ('涉嫌', 0.0054539960394905385),
#  ('人民法院', 0.005358019115605961),
#  ('公安局', 0.00535766896649718)]
# '************************************************************'
# Most 20 Important words in TOPIC 57 :
#
# [('事故', 0.02207990830421064),
#  ('交警', 0.018371437131119567),
#  ('司机', 0.017061963175200937),
#  ('一辆', 0.017049367364909758),
#  ('驾驶', 0.01676627443838146),
#  ('民警', 0.012881943449505844),
#  ('车辆', 0.012100121858770107),
#  ('货车', 0.011645308638006363),
#  ('行驶', 0.010717494288043517),
#  ('乘客', 0.009483716102468953),
#  ('轿车', 0.009388872311965633),
#  ('摩托车', 0.009347183255085207),
#  ('托车', 0.009341714741542653),
#  ('摩托', 0.009126915334780538),
#  ('交通事故', 0.008883498729301935),
#  ('驾驶员', 0.008851397724417705),
#  ('车祸', 0.008794076418519578),
#  ('通事', 0.008780537721055094),
#  ('车上', 0.008771903413619562),
#  ('男子', 0.008611131106921634)]
# '************************************************************'
# Most 20 Important words in TOPIC 58 :
#
# [('公交', 0.018393921397627182),
#  ('地铁', 0.015405907491470342),
#  ('路口', 0.014273401714423949),
#  ('交通', 0.013967987371770702),
#  ('线路', 0.012117917834395288),
#  ('路段', 0.011853203251298444),
#  ('高速', 0.011641248391154897),
#  ('车站', 0.010506177400691485),
#  ('铁路', 0.00929301903199831),
#  ('车辆', 0.009161740110124066),
#  ('列车', 0.008871440207149407),
#  ('大道', 0.008664745325316088),
#  ('停车', 0.008075522969236752),
#  ('换乘', 0.0074718276476732565),
#  ('道路', 0.007288930093602066),
#  ('动车', 0.007057415641093469),
#  ('施工', 0.006918789143213057),
#  ('公路', 0.006906628650017212),
#  ('站点', 0.006669069696709875),
#  ('高铁', 0.006547014962975169)]
# '************************************************************'

# %% [markdown]
# 主题归并

# %%
for i in tqdm(range(20)):
    # Calculate cosine similarity
    similarities = cosine_similarity(tf_idf.T)
    np.fill_diagonal(similarities, 0)

    # Extract label to merge into and from where
    topic_sizes = docs_df.groupby(['Topic']).count().sort_values("Doc", ascending=False).reset_index()
    topic_to_merge = topic_sizes.iloc[-1].Topic
    topic_to_merge_into = np.argmax(similarities[topic_to_merge + 1]) - 1

    # Adjust topics
    docs_df.loc[docs_df.Topic == topic_to_merge, "Topic"] = topic_to_merge_into
    old_topics = docs_df.sort_values("Topic").Topic.unique()
    map_topics = {old_topic: index - 1 for index, old_topic in enumerate(old_topics)}
    docs_df.Topic = docs_df.Topic.map(map_topics)
    docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

    # Calculate new topic words
    m = len(data)
    tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m)
    top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20)

topic_sizes = extract_topic_sizes(docs_df); topic_sizes.head(10)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#   5%|▌         | 1/20 [00:58<18:36, 58.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  10%|█         | 2/20 [01:58<17:53, 59.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  15%|█▌        | 3/20 [02:56<16:40, 58.85s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  20%|██        | 4/20 [03:57<15:49, 59.35s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  25%|██▌       | 5/20 [04:57<14:56, 59.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  30%|███       | 6/20 [05:58<14:01, 60.11s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  35%|███▌      | 7/20 [06:59<13:07, 60.56s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  40%|████      | 8/20 [08:01<12:09, 60.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  45%|████▌     | 9/20 [09:01<11:07, 60.64s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  50%|█████     | 10/20 [10:00<10:00, 60.10s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  55%|█████▌    | 11/20 [10:59<08:58, 59.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  60%|██████    | 12/20 [11:59<07:57, 59.73s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  65%|██████▌   | 13/20 [12:58<06:56, 59.52s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  70%|███████   | 14/20 [13:58<05:59, 59.89s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  75%|███████▌  | 15/20 [15:00<05:01, 60.38s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  80%|████████  | 16/20 [16:01<04:02, 60.65s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  85%|████████▌ | 17/20 [17:03<03:03, 61.16s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  90%|█████████ | 18/20 [18:06<02:02, 61.49s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  95%|█████████▌| 19/20 [19:07<01:01, 61.58s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 100%|██████████| 20/20 [20:10<00:00, 60.52s/it]
#     Topic   Size
# 0      -1  37052
# 24     23   4815
# 2       1   4173
# 15     14   3730
# 23     22   3360
# 6       5   3265
# 35     34   1464
# 31     30   1445
# 10      9   1247
# 37     36   1165

# %% [markdown]
# 查看归并之后的主题数

# %%
len(docs_per_topic.Doc.tolist())
# Out:
# 40

# %% [markdown]
# 查看归并后的所有主题及其对应的主题词列表：

# %%
from pprint import pprint
for i in list(range(len(top_n_words) - 1)):
    print('Most 20 Important words in TOPIC {} :\n'.format(i))
    pprint(top_n_words[i])
    pprint('***'*20)
# Out:
# Most 20 Important words in TOPIC 0 :
#
# [('股东', 0.025013614213879234),
#  ('表决', 0.023604370026441435),
#  ('董事', 0.023043074033778498),
#  ('股东大会', 0.01944619849949937),
#  ('议案', 0.018650535619570807),
#  ('董事会', 0.018444309533152112),
#  ('东大', 0.01832243288602126),
#  ('股份', 0.018068483461824658),
#  ('审议', 0.01553672963790957),
#  ('大会', 0.01397963112291974),
#  ('股份有限', 0.013820640971283717),
#  ('投票', 0.012835003480468942),
#  ('年度', 0.01235268154399561),
#  ('公告', 0.01223274828683492),
#  ('有限公司', 0.012224227838338394),
#  ('弃权', 0.0118878258660968),
#  ('会议', 0.011797205322416736),
#  ('本次', 0.011781005005124377),
#  ('有限', 0.011587254487795956),
#  ('监事', 0.01140488266238262)]
# '************************************************************'
# Most 20 Important words in TOPIC 1 :
#
# [('搞笑', 0.015527073422293994),
#  ('儿歌', 0.013672971944820955),
#  ('熊出没', 0.012053251802007553),
#  ('源源', 0.010594933141373703),
#  ('幽默', 0.01015714319030272),
#  ('出没', 0.010053026841199303),
#  ('视频', 0.009804047605505633),
#  ('奥特曼', 0.009500069779994468),
#  ('奥特', 0.009455795876181321),
#  ('特曼', 0.008993285701080926),
#  ('舞蹈', 0.008834293072040818),
#  ('高清', 0.007664163279311083),
#  ('美女', 0.007053178680674881),
#  ('解说', 0.006641890091641406),
#  ('佩奇', 0.0064594290466465564),
#  ('蛋壳', 0.00625622600403447),
#  ('清版', 0.0062158865364495075),
#  ('成语', 0.006104846305820226),
#  ('完整版', 0.006073374780027308),
#  ('鸡蛋壳', 0.005990830966063933)]
# '************************************************************'
# Most 20 Important words in TOPIC 2 :
#
# [('装修', 0.03049505755881105),
#  ('家具', 0.013913269516002795),
#  ('装饰', 0.0126138006990555),
#  ('卧室', 0.012379926194663412),
#  ('客厅', 0.011556005685277537),
#  ('设计', 0.010992843176138465),
#  ('空间', 0.010517872119713749),
#  ('阳台', 0.010346130420036551),
#  ('厨房', 0.010303630502222074),
#  ('户型', 0.009137846897590998),
#  ('瓷砖', 0.00906156998087767),
#  ('墙面', 0.009049676556241053),
#  ('地板', 0.008779002264418875),
#  ('家居', 0.008230728404242181),
#  ('风格', 0.008214823396781349),
#  ('室内', 0.007727620614534104),
#  ('沙发', 0.007409853823253382),
#  ('设计师', 0.007104024137598204),
#  ('施工', 0.007067279503473138),
#  ('衣柜', 0.006946465276698826)]
# '************************************************************'
# Most 20 Important words in TOPIC 3 :
#
# [('能源', 0.028360858234111306),
#  ('新能源', 0.024753189969067817),
#  ('电动', 0.01925395119032845),
#  ('充电', 0.016742142621170845),
#  ('电池', 0.01624231591515172),
#  ('发电', 0.012738741460201895),
#  ('汽车', 0.012509738461392852),
#  ('电动汽车', 0.01122155315797276),
#  ('光伏', 0.010864042437551326),
#  ('电力', 0.009875838021425517),
#  ('电动车', 0.009361132244314214),
#  ('电网', 0.009141904058689958),
#  ('电价', 0.008667623542175618),
#  ('动车', 0.008474706534893075),
#  ('太阳能', 0.008470185914839735),
#  ('补贴', 0.007646809617526489),
#  ('风电', 0.007168856023171735),
#  ('可再生', 0.006548002776111498),
#  ('再生能源', 0.006523646322654),
#  ('机组', 0.006514984618297626)]
# '************************************************************'
# Most 20 Important words in TOPIC 4 :
#
# [('刹车', 0.027872333455383275),
#  ('车辆', 0.016536348298106417),
#  ('轮胎', 0.01576290314309972),
#  ('驾驶', 0.015539015300946164),
#  ('制动', 0.01317244092488016),
#  ('行驶', 0.01272444936180463),
#  ('车主', 0.012020156865715535),
#  ('刹车片', 0.010509064015722281),
#  ('开车', 0.01043016231530484),
#  ('司机', 0.009769802920462213),
#  ('事故', 0.00950369242632024),
#  ('停车', 0.00895529976468672),
#  ('后车', 0.008221391273507551),
#  ('汽车', 0.0077288921418192155),
#  ('货车', 0.0076563977779414245),
#  ('车速', 0.007403444031744543),
#  ('前车', 0.0073017567088752315),
#  ('违章', 0.007016426711789389),
#  ('手刹', 0.0069154370400103795),
#  ('离合', 0.006849437665797272)]
# '************************************************************'
# Most 20 Important words in TOPIC 5 :
#
# [('比赛', 0.016097145021831565),
#  ('球队', 0.011813333880843099),
#  ('赛季', 0.01095529816557858),
#  ('足球', 0.010261472636581703),
#  ('球员', 0.01023825322425794),
#  ('体育', 0.008991317008098187),
#  ('联赛', 0.008730812152834283),
#  ('冠军', 0.007925182749954986),
#  ('世界杯', 0.006861992814856074),
#  ('国足', 0.006681009485053334),
#  ('球迷', 0.0063192418086696735),
#  ('赛事', 0.006308271086732663),
#  ('决赛', 0.006097806269734166),
#  ('主场', 0.005974716070727906),
#  ('奥运', 0.005700258449511592),
#  ('进球', 0.005534135820899839),
#  ('教练', 0.005512237954949187),
#  ('俱乐部', 0.004806798613557501),
#  ('选手', 0.004568420166609865),
#  ('巴西', 0.004448690177441306)]
# '************************************************************'
# Most 20 Important words in TOPIC 6 :
#
# [('版权', 0.014798710034652334),
#  ('作者', 0.012216730361341164),
#  ('豆瓣', 0.011851398480253716),
#  ('文章', 0.010595312782735776),
#  ('点击', 0.009023851140272357),
#  ('转载', 0.008680019107404156),
#  ('阅读', 0.007764868460833222),
#  ('内存', 0.007535974356705716),
#  ('删除', 0.0073051633185391126),
#  ('赌场', 0.006819424199627819),
#  ('演讲集', 0.006700165336796911),
#  ('下载', 0.0066222820504855924),
#  ('原文', 0.006461719745780071),
#  ('盗版', 0.006425608572377441),
#  ('单词', 0.006335944786063399),
#  ('筹码', 0.0060298014832419365),
#  ('调用', 0.0059544005859370275),
#  ('兔子', 0.0059278613422784135),
#  ('留言', 0.00591089383267207),
#  ('二维', 0.005483125620806645)]
# '************************************************************'
# Most 20 Important words in TOPIC 7 :
#
# [('车型', 0.02311015571689087),
#  ('新车', 0.014096010819693737),
#  ('发动机', 0.014022761450216175),
#  ('动机', 0.013455322120328598),
#  ('发动', 0.013360025289918757),
#  ('全新', 0.011174411716774071),
#  ('汽车', 0.009580280001171147),
#  ('内饰', 0.009475710134334755),
#  ('车身', 0.009150567157838426),
#  ('动力', 0.008816803733912746),
#  ('配置', 0.008761905779004606),
#  ('变速', 0.008491934433137767),
#  ('外观', 0.008093962431246304),
#  ('销量', 0.00785215238698179),
#  ('奔驰', 0.007360284632365193),
#  ('变速箱', 0.0070539570231741055),
#  ('设计', 0.007015469992742745),
#  ('搭载', 0.006882203364474632),
#  ('采用', 0.006741782005920768),
#  ('座椅', 0.006633681312762198)]
# '************************************************************'
# Most 20 Important words in TOPIC 8 :
#
# [('万万', 0.03913050214492261),
#  ('搜狐', 0.0271327497255251),
#  ('报错', 0.022295524336159864),
#  ('座椅', 0.021810211701511782),
#  ('有奖', 0.02129480430997302),
#  ('经销商', 0.020840509588944144),
#  ('经销', 0.02053079714195346),
#  ('充足', 0.019171961641322215),
#  ('手动', 0.01734825596763373),
#  ('询价', 0.01573399871966166),
#  ('后排', 0.015558348097880668),
#  ('车型', 0.015558022703793362),
#  ('优惠', 0.015180067076256904),
#  ('汽车', 0.015074960009658266),
#  ('悬挂', 0.014941351954326781),
#  ('自动', 0.014382747997768794),
#  ('调节', 0.014357006045428949),
#  ('电动', 0.014245036427153917),
#  ('车身', 0.013655033148249804),
#  ('发动机', 0.013609800907198807)]
# '************************************************************'
# Most 20 Important words in TOPIC 9 :
#
# [('医院', 0.015514323451529135),
#  ('医疗', 0.014279972921314714),
#  ('患者', 0.009151421487996643),
#  ('医生', 0.00913873998946425),
#  ('治疗', 0.008022937155130859),
#  ('药品', 0.007835798482970564),
#  ('医药', 0.00712014282869463),
#  ('中医', 0.007078415548988663),
#  ('医学', 0.007062204084977281),
#  ('健康', 0.006494944853351869),
#  ('卫生', 0.006468714575473915),
#  ('临床', 0.006394615830042564),
#  ('手术', 0.0061192921386986005),
#  ('肿瘤', 0.005971176966091948),
#  ('细胞', 0.005110772168994075),
#  ('疫苗', 0.005056148636742999),
#  ('医保', 0.005049891027044059),
#  ('病人', 0.004759049790533374),
#  ('癌症', 0.004709857682962315),
#  ('医疗机构', 0.004432409171522762)]
# '************************************************************'
# Most 20 Important words in TOPIC 10 :
#
# [('二维码', 0.031201516999929),
#  ('二维', 0.03104705213610017),
#  ('订阅', 0.02888561627923161),
#  ('简介', 0.028047634944203717),
#  ('别关', 0.027303462574043227),
#  ('识别', 0.02704180928566815),
#  ('免费', 0.02181836161137731),
#  ('女人', 0.020948067030099958),
#  ('信号', 0.01800913678332429),
#  ('关注', 0.014078737837449722),
#  ('中二', 0.012415877149935613),
#  ('男人', 0.01119768763623508),
#  ('每天', 0.010677188461427619),
#  ('搭配', 0.008405667287254708),
#  ('点击', 0.008330767791507354),
#  ('穿衣', 0.008223824307558074),
#  ('轻松', 0.00784242767545962),
#  ('排毒', 0.00757083651006539),
#  ('添加', 0.007232440517723846),
#  ('先点', 0.007181329530679199)]
# '************************************************************'
# Most 20 Important words in TOPIC 11 :
#
# [('游戏', 0.04841348039923061),
#  ('玩家', 0.03414089428688768),
#  ('英雄', 0.008586730570044785),
#  ('玩法', 0.008287492266279194),
#  ('技能', 0.006970801720260514),
#  ('装备', 0.006887580664940868),
#  ('任天堂', 0.006737656183761499),
#  ('天堂', 0.005409690777624077),
#  ('体验', 0.0052343870125167846),
#  ('战斗', 0.0050541570264731025),
#  ('移动游戏', 0.0048469677322010045),
#  ('版本', 0.0048368110204891155),
#  ('让玩家', 0.004787812700564632),
#  ('显卡', 0.004781495779154725),
#  ('一款', 0.004535336694522095),
#  ('伤害', 0.004346891619222055),
#  ('三国', 0.004277539928967857),
#  ('移动', 0.0040383238448107655),
#  ('这款', 0.003990107893725278),
#  ('角色', 0.003867114802626994)]
# '************************************************************'
# Most 20 Important words in TOPIC 12 :
#
# [('搭配', 0.026006313955085063),
#  ('时尚', 0.01727621169393933),
#  ('牛仔', 0.01588396929507591),
#  ('外套', 0.014834239991487915),
#  ('毛衣', 0.013546459622048592),
#  ('针织', 0.012844910223100579),
#  ('衬衫', 0.011220439196802191),
#  ('大衣', 0.009962134975869933),
#  ('版型', 0.009779955417122605),
#  ('条纹', 0.009674983484154498),
#  ('面料', 0.009306626976080314),
#  ('款式', 0.009177233124882786),
#  ('宽松', 0.008890183374839275),
#  ('时髦', 0.008614603035157455),
#  ('衣裙', 0.008483121351709698),
#  ('黑色', 0.008286693467534693),
#  ('秋冬', 0.008095834862889213),
#  ('连衣', 0.007962584033852943),
#  ('牛仔裤', 0.007933415573131417),
#  ('优雅', 0.007836962474864708)]
# '************************************************************'
# Most 20 Important words in TOPIC 13 :
#
# [('肌肤', 0.03101383483608523),
#  ('皮肤', 0.02815655195795336),
#  ('化妆', 0.012826537843665239),
#  ('面部', 0.01133316970754671),
#  ('保湿', 0.011222128768331799),
#  ('护肤', 0.011208261225094765),
#  ('眼睛', 0.010879364091495971),
#  ('脸部', 0.010519058837157697),
#  ('化妆水', 0.010156886245976708),
#  ('眼部', 0.009643446720531603),
#  ('眼皮', 0.009632817171041155),
#  ('手术', 0.008779497949584353),
#  ('面膜', 0.00877205908545021),
#  ('精华', 0.008026192328566743),
#  ('色素', 0.00798768629660245),
#  ('祛斑', 0.007914137011954741),
#  ('毛孔', 0.007862509214830848),
#  ('眼线', 0.007752889368463512),
#  ('色斑', 0.007588494745472868),
#  ('双眼', 0.007484750518867396)]
# '************************************************************'
# Most 20 Important words in TOPIC 14 :
#
# [('考试', 0.007902342610431948),
#  ('学生', 0.006955311795360358),
#  ('教育', 0.006650132859256686),
#  ('考生', 0.006622958746999335),
#  ('学校', 0.00636044085447386),
#  ('家长', 0.005339795449739366),
#  ('教师', 0.005324943015225707),
#  ('学习', 0.004971131888210113),
#  ('大学', 0.004880576042736733),
#  ('招生', 0.004650154029168649),
#  ('老师', 0.004592006879542813),
#  ('孩子', 0.0044060314127661055),
#  ('报名', 0.0043607688839811904),
#  ('教学', 0.0042728196202593705),
#  ('高考', 0.004144811025607766),
#  ('英语', 0.004104036170055219),
#  ('小学', 0.004058143606715937),
#  ('成绩', 0.0040178729520920446),
#  ('留学', 0.0040091366797526595),
#  ('报考', 0.004002858493977206)]
# '************************************************************'
# Most 20 Important words in TOPIC 15 :
#
# [('手机', 0.027784741666612486),
#  ('三星', 0.020895506187843485),
#  ('小米', 0.017460408724934803),
#  ('华为', 0.011018719315166615),
#  ('摄像', 0.009201193287581105),
#  ('像素', 0.008906980453243264),
#  ('像头', 0.008893742042788866),
#  ('摄像头', 0.008889752270349674),
#  ('理器', 0.008631768842499844),
#  ('处理器', 0.00860629280891685),
#  ('电池', 0.007953808757723063),
#  ('智能手机', 0.007665591155247993),
#  ('能手', 0.007401769182866888),
#  ('屏幕', 0.007302809643368592),
#  ('机身', 0.0071413462733700105),
#  ('智能', 0.0069034045981970936),
#  ('用户', 0.006424860390260831),
#  ('充电', 0.006157823430646222),
#  ('采用', 0.005766752800743607),
#  ('内存', 0.005717312573974626)]
# '************************************************************'
# Most 20 Important words in TOPIC 16 :
#
# [('苹果', 0.07223933236331835),
#  ('苹果公司', 0.016027403942221775),
#  ('手表', 0.010217519986033364),
#  ('乔布', 0.009207365873463607),
#  ('乔布斯', 0.009207365873463607),
#  ('布斯', 0.00824258247150454),
#  ('手机', 0.007308019174698066),
#  ('英寸', 0.007105036702180068),
#  ('用户', 0.007063189865686308),
#  ('屏幕', 0.006894160302753089),
#  ('库克', 0.006282638425871421),
#  ('以旧换新', 0.005904691672128745),
#  ('设备', 0.0059026863593772665),
#  ('能手', 0.0058283247607338684),
#  ('键盘', 0.0057798932790425195),
#  ('推出', 0.005714967513915819),
#  ('发布', 0.005666856581154357),
#  ('富士康', 0.005537120293360812),
#  ('换新', 0.005356279998320032),
#  ('果在', 0.0053171483932647045)]
# '************************************************************'
# Most 20 Important words in TOPIC 17 :
#
# [('气温', 0.015765743772660545),
#  ('气象', 0.015484861132539517),
#  ('天气', 0.01518757986575201),
#  ('台风', 0.013546793635857358),
#  ('暴雨', 0.013354977814069809),
#  ('降雨', 0.012031937916272209),
#  ('供热', 0.00845391718317541),
#  ('气象台', 0.007965630457822465),
#  ('降水', 0.007781526372500694),
#  ('高温', 0.007205504083306814),
#  ('北部', 0.007017843689968349),
#  ('地区', 0.006943590500262016),
#  ('冷空气', 0.006935493223661709),
#  ('多云', 0.006837723731045406),
#  ('预警', 0.00663307682433913),
#  ('毫米', 0.006604102361379039),
#  ('南部', 0.00653025731283896),
#  ('高气', 0.006098070852949262),
#  ('预报', 0.006091312842292324),
#  ('空气', 0.005806022468103133)]
# '************************************************************'
# Most 20 Important words in TOPIC 18 :
#
# [('宝宝', 0.026837457043524464),
#  ('孕妇', 0.021175153069632083),
#  ('胎儿', 0.019935854953786133),
#  ('怀孕', 0.019668086936311738),
#  ('孕期', 0.01584119380509836),
#  ('子宫', 0.014620813188280112),
#  ('妈妈', 0.014382215261184826),
#  ('妊娠', 0.01222095131793275),
#  ('分娩', 0.011803698329452375),
#  ('准妈妈', 0.011711715200358965),
#  ('产后', 0.010996506293397977),
#  ('胎盘', 0.010438306328890694),
#  ('发育', 0.009876745845507085),
#  ('排卵', 0.00891580188988696),
#  ('女性', 0.008700025023558438),
#  ('辐射', 0.00792225146495163),
#  ('婴儿', 0.00761434262336563),
#  ('产妇', 0.007469670358825734),
#  ('食物', 0.00745401174006123),
#  ('激素', 0.007363288538109559)]
# '************************************************************'
# Most 20 Important words in TOPIC 19 :
#
# [('关节', 0.013134583571839695),
#  ('健身', 0.010794198153300894),
#  ('治疗', 0.0104467252940965),
#  ('疼痛', 0.010113519156898919),
#  ('跑步', 0.010110568912155922),
#  ('患者', 0.009838441508731283),
#  ('血管', 0.009149779847103),
#  ('肌肉', 0.008913422019065989),
#  ('神经', 0.008554754947220473),
#  ('症状', 0.008506674262175096),
#  ('运动', 0.008131276074676742),
#  ('身体', 0.00786516133611535),
#  ('疾病', 0.007541869894241566),
#  ('动作', 0.007426564082506396),
#  ('锻炼', 0.00708156518795293),
#  ('骨质', 0.006822058381883538),
#  ('颈椎', 0.006292040848916792),
#  ('训练', 0.0060501407936972285),
#  ('咽炎', 0.005888331941849824),
#  ('血压', 0.005730989031632479)]
# '************************************************************'
# Most 20 Important words in TOPIC 20 :
#
# [('放入', 0.03239210896324553),
#  ('倒入', 0.021804175904089174),
#  ('适量', 0.02063590339557941),
#  ('鸡蛋', 0.02046004925034411),
#  ('翻炒', 0.015898500751996322),
#  ('少许', 0.01582321012571832),
#  ('加入', 0.015450761070795764),
#  ('辣椒', 0.014838327264127179),
#  ('做法', 0.014166216909926874),
#  ('均匀', 0.01325233029615767),
#  ('小火', 0.012647820163426362),
#  ('豆腐', 0.012596180584653546),
#  ('切成', 0.012522042161075829),
#  ('分钟', 0.012513945908797446),
#  ('料酒', 0.012251524285183004),
#  ('生抽', 0.012085817359741633),
#  ('洗净', 0.012020039015685316),
#  ('即可', 0.011501519849341956),
#  ('搅拌', 0.011493046024353672),
#  ('胡椒', 0.011125797788329927)]
# '************************************************************'
# Most 20 Important words in TOPIC 21 :
#
# [('维生素', 0.020142341099318336),
#  ('维生', 0.020069259076621736),
#  ('营养', 0.01760646276462454),
#  ('含有', 0.01758179592413707),
#  ('水果', 0.013969171158906448),
#  ('食用', 0.01231904021842712),
#  ('食物', 0.011890729839299147),
#  ('蛋白', 0.010830313920016925),
#  ('香蕉', 0.010560871065194667),
#  ('作用', 0.010489167038560426),
#  ('功效', 0.010488298279166131),
#  ('萝卜', 0.010070374643021738),
#  ('物质', 0.009967772619740429),
#  ('含量', 0.009762923038034433),
#  ('人体', 0.009567942064310015),
#  ('富含', 0.009228769904653536),
#  ('蛋白质', 0.00922367415626481),
#  ('白质', 0.009198521503736673),
#  ('枸杞', 0.00919465188601822),
#  ('脂肪', 0.008896196304391672)]
# '************************************************************'
# Most 20 Important words in TOPIC 22 :
#
# [('电影', 0.009123607971680278),
#  ('导演', 0.006695709645045901),
#  ('节目', 0.0065977760072051935),
#  ('演员', 0.006315771756510618),
#  ('观众', 0.006253511255958489),
#  ('歌手', 0.0048327414838248185),
#  ('网友', 0.0047093170806211185),
#  ('主演', 0.0041497668111723255),
#  ('影片', 0.004081819559795581),
#  ('明星', 0.00400884675635393),
#  ('音乐', 0.003975924825574597),
#  ('娱乐', 0.003929100116599844),
#  ('饰演', 0.0038704123510004923),
#  ('粉丝', 0.003606024047432892),
#  ('电视', 0.0034885777859544535),
#  ('角色', 0.0034623359134266147),
#  ('拍摄', 0.0034502582268510907),
#  ('电视剧', 0.0033878017130019498),
#  ('卫视', 0.0032656332095534774),
#  ('婚礼', 0.0031486515221233443)]
# '************************************************************'
# Most 20 Important words in TOPIC 23 :
#
# [('男人', 0.0034629069492823797),
#  ('女人', 0.00304899114673965),
#  ('人生', 0.002460518403474777),
#  ('爱情', 0.0021725016078857034),
#  ('喜欢', 0.0021210750248616796),
#  ('文化', 0.001866076231635851),
#  ('旅游', 0.001850213169906149),
#  ('生活', 0.0018466591319529538),
#  ('景区', 0.001823950635331619),
#  ('公园', 0.0017656550305885622),
#  ('婚姻', 0.0017591285345177697),
#  ('感情', 0.0017456318161347766),
#  ('艺术', 0.001737749064980937),
#  ('朋友', 0.0017261508324804586),
#  ('知道', 0.0016619975546412688),
#  ('风景', 0.0016416875138991946),
#  ('幸福', 0.0016017339843925164),
#  ('一种', 0.0016006185907616606),
#  ('个人', 0.0016002353453806626),
#  ('不要', 0.0015850780550567649)]
# '************************************************************'
# Most 20 Important words in TOPIC 24 :
#
# [('原油', 0.038046212109209415),
#  ('油价', 0.030465741874617168),
#  ('石油', 0.01911680127698545),
#  ('万桶', 0.017394449528875214),
#  ('库存', 0.016071644243878875),
#  ('天然气', 0.015817566621597945),
#  ('油库', 0.015602176499526886),
#  ('止损', 0.013448499180161581),
#  ('美元', 0.01344790430410626),
#  ('行情', 0.012595951949572652),
#  ('天然', 0.01255168675151955),
#  ('产量', 0.011157117914687159),
#  ('油价格', 0.010309489994951194),
#  ('附近', 0.0101818815881529),
#  ('减产', 0.009932866373230074),
#  ('操作', 0.009311720222065868),
#  ('反弹', 0.008444701938166061),
#  ('支撑', 0.008210261598733408),
#  ('均线', 0.007817278443937719),
#  ('产油', 0.007692440470823984)]
# '************************************************************'
# Most 20 Important words in TOPIC 25 :
#
# [('机器人', 0.019257877360973254),
#  ('机器', 0.019042828400681003),
#  ('智能', 0.008050197055962957),
#  ('人工智能', 0.007129389075231477),
#  ('人工', 0.006194712657648918),
#  ('展会', 0.005666362873329147),
#  ('无人机', 0.005637525974648237),
#  ('人机', 0.005601072755112636),
#  ('创新', 0.005309610333143783),
#  ('无人', 0.005129373650310671),
#  ('产业', 0.004809375119004739),
#  ('参展', 0.004715295002794874),
#  ('科技', 0.00469674262235695),
#  ('展览', 0.004264181835201699),
#  ('国际', 0.004176065826960809),
#  ('领域', 0.004109710411904585),
#  ('创业', 0.003995872246058434),
#  ('大会', 0.003907922185529684),
#  ('论坛', 0.003889977377215754),
#  ('全球', 0.0038244493316980585)]
# '************************************************************'
# Most 20 Important words in TOPIC 26 :
#
# [('网站', 0.016549459123227365),
#  ('关键词', 0.012193673249846439),
#  ('索引', 0.01065626407422993),
#  ('搜索引擎', 0.010376234080576056),
#  ('教程', 0.01000774651195495),
#  ('搜索', 0.009169972972293845),
#  ('营销', 0.008993269686949754),
#  ('用户', 0.008941742149619469),
#  ('引擎', 0.008414015181818247),
#  ('页面', 0.007819032210625729),
#  ('关键', 0.007655841751073344),
#  ('优化', 0.007069959205157998),
#  ('广告', 0.006602228591103043),
#  ('网页', 0.006475570627730946),
#  ('内容', 0.006357858279621241),
#  ('媒体', 0.004938782893687964),
#  ('文章', 0.004711818184807177),
#  ('新闻', 0.0046307255722642295),
#  ('小程', 0.0045336027906659965),
#  ('平台', 0.004531152929893835)]
# '************************************************************'
# Most 20 Important words in TOPIC 27 :
#
# [('互联网', 0.011494774108708396),
#  ('互联', 0.011366169402006212),
#  ('联网', 0.011346159929072291),
#  ('阿里', 0.008431104988604176),
#  ('电商', 0.007883545109228462),
#  ('用户', 0.007271504589064539),
#  ('营销', 0.00598908669078796),
#  ('数据', 0.005445322302539164),
#  ('大数', 0.005120190465517773),
#  ('物流', 0.004940504888975684),
#  ('平台', 0.004660737857776456),
#  ('移动', 0.00445179956540425),
#  ('消费', 0.004433000555866448),
#  ('阿里巴巴', 0.004303740763679063),
#  ('网络', 0.00429006161528474),
#  ('模式', 0.0042483075712289944),
#  ('传统', 0.004236176405224212),
#  ('运营', 0.004205026511153598),
#  ('线下', 0.0040671364604547),
#  ('流量', 0.003912177577616226)]
# '************************************************************'
# Most 20 Important words in TOPIC 28 :
#
# [('房价', 0.017973171437667343),
#  ('地产', 0.016364318047023645),
#  ('房地', 0.015046264095074095),
#  ('房地产', 0.015041351246239976),
#  ('住房', 0.014932115038633715),
#  ('购房', 0.012161422443253557),
#  ('楼市', 0.01098090777617582),
#  ('住宅', 0.009812157950834904),
#  ('新政', 0.009068780470833617),
#  ('积金', 0.008932688185184355),
#  ('公积金', 0.008930962501616147),
#  ('公积', 0.008762738858850719),
#  ('成交', 0.008728560186329616),
#  ('首付', 0.008482950215881373),
#  ('城市', 0.00807788112701297),
#  ('贷款', 0.007506276817384244),
#  ('套房', 0.007462439376967311),
#  ('平方米', 0.007373560163943696),
#  ('二手房', 0.007354191213788643),
#  ('平方', 0.00711446696790747)]
# '************************************************************'
# Most 20 Important words in TOPIC 29 :
#
# [('同比', 0.02581279472350897),
#  ('净利', 0.022391161999908746),
#  ('净利润', 0.02108468441304787),
#  ('比增', 0.019642526489798185),
#  ('利润', 0.019220607144836196),
#  ('亿元', 0.016051012477432066),
#  ('季度', 0.01602776718567826),
#  ('增长', 0.014617394882703836),
#  ('业绩', 0.013975747029385904),
#  ('三季', 0.013107384449209872),
#  ('营业', 0.012605102923203436),
#  ('收入', 0.011429607630231223),
#  ('三季度', 0.01129553560312355),
#  ('每股', 0.010823692271058777),
#  ('同期', 0.010350330385613032),
#  ('亏损', 0.009122514974005595),
#  ('归属', 0.009023283671442827),
#  ('归属于', 0.00890653109553921),
#  ('实现', 0.008849194437001998),
#  ('下降', 0.008810068846398756)]
# '************************************************************'
# Most 20 Important words in TOPIC 30 :
#
# [('长征', 0.0075105414792318494),
#  ('红军', 0.005998210863436135),
#  ('政治', 0.0055578327833006765),
#  ('书记', 0.005538880128527685),
#  ('希拉里', 0.00539336109739484),
#  ('希拉', 0.005366777667359897),
#  ('拉里', 0.005232081287861009),
#  ('中央', 0.005056297533580781),
#  ('领导', 0.004778219477203695),
#  ('总统', 0.004435694834125286),
#  ('干部', 0.004415902751386041),
#  ('党员', 0.0042664915518406815),
#  ('朝鲜', 0.00424189034918857),
#  ('共产', 0.00415721592119712),
#  ('会议', 0.004141545209792455),
#  ('特朗普', 0.00407782788444673),
#  ('建设', 0.003824432437625844),
#  ('主义', 0.0037688075400248502),
#  ('共产党', 0.0037661145362545283),
#  ('习近平', 0.003751828053869676)]
# '************************************************************'
# Most 20 Important words in TOPIC 31 :
#
# [('海军', 0.016459387392725112),
#  ('潜艇', 0.01632765656777783),
#  ('俄罗斯', 0.016261761445877),
#  ('导弹', 0.01617229688675938),
#  ('罗斯', 0.01571922887323047),
#  ('也门', 0.013482845360661985),
#  ('航母', 0.013359143420076575),
#  ('武装', 0.013284894452130703),
#  ('战斗', 0.011418845697925017),
#  ('军事', 0.0111459986646038),
#  ('武器', 0.010060710425091018),
#  ('空军', 0.009766696381770327),
#  ('战斗机', 0.008635902763491049),
#  ('演习', 0.008532018200610156),
#  ('国海军', 0.008465467073330431),
#  ('战机', 0.00845068951292716),
#  ('沙特', 0.008283690249049078),
#  ('国防', 0.007345965106692747),
#  ('部队', 0.007040111832044213),
#  ('作战', 0.006966170710143271)]
# '************************************************************'
# Most 20 Important words in TOPIC 32 :
#
# [('联储', 0.0212249749797933),
#  ('美元', 0.020622962291828688),
#  ('美联储', 0.019265092444661035),
#  ('黄金', 0.018997223796856946),
#  ('加息', 0.015913471426506655),
#  ('人民币', 0.015202784819817584),
#  ('汇率', 0.013405922389678757),
#  ('贬值', 0.012858219094842117),
#  ('欧元', 0.012427611534707344),
#  ('金价', 0.012235484111229784),
#  ('央行', 0.011521852011813405),
#  ('货币', 0.010352967386123697),
#  ('预期', 0.010349276689475887),
#  ('白银', 0.009500410391808612),
#  ('人民', 0.008835944388048597),
#  ('英镑', 0.007994681805687937),
#  ('指数', 0.007602836180027054),
#  ('盎司', 0.007548847925568461),
#  ('现货', 0.007342372137826196),
#  ('支撑', 0.007273453817536594)]
# '************************************************************'
# Most 20 Important words in TOPIC 33 :
#
# [('消防', 0.04984451254590427),
#  ('火灾', 0.021925854467756075),
#  ('爆炸', 0.01862111247770127),
#  ('起火', 0.016397299892826026),
#  ('灭火', 0.013980052153941354),
#  ('救援', 0.012478669026268882),
#  ('官兵', 0.012447722771118377),
#  ('防火', 0.011201719150026294),
#  ('事故', 0.011003511138633659),
#  ('火势', 0.010841831353308658),
#  ('消防官兵', 0.010775158148727267),
#  ('现场', 0.00996949152140808),
#  ('被困', 0.009707649547351049),
#  ('消防安全', 0.008967155828205984),
#  ('扑灭', 0.008955707747098026),
#  ('着火', 0.008714171121786267),
#  ('大火', 0.008479140159907349),
#  ('面粉', 0.008102799872069025),
#  ('发生', 0.007840762718876567),
#  ('消防员', 0.007479500955159475)]
# '************************************************************'
# Most 20 Important words in TOPIC 34 :
#
# [('个股', 0.008665757219400879),
#  ('大盘', 0.008290534097389632),
#  ('股市', 0.007896780220589593),
#  ('行情', 0.007729514637667982),
#  ('投资者', 0.007625478415013845),
#  ('股票', 0.007435154842360879),
#  ('板块', 0.007219036633770822),
#  ('涨停', 0.006929027909635186),
#  ('上涨', 0.006561993907696608),
#  ('震荡', 0.0064320378723607035),
#  ('股价', 0.0063982602625474155),
#  ('指数', 0.00627025338388324),
#  ('涨幅', 0.005819407407864534),
#  ('创业板', 0.005727106720485249),
#  ('资金', 0.005662896442455079),
#  ('成交', 0.005444949426629484),
#  ('操作', 0.005399911900687964),
#  ('走势', 0.00503303000243423),
#  ('均线', 0.005021728564558337),
#  ('趋势', 0.004965894048132765)]
# '************************************************************'
# Most 20 Important words in TOPIC 35 :
#
# [('发行', 0.01090618155140865),
#  ('证券', 0.010820772042031466),
#  ('申购', 0.008716992810688592),
#  ('份额', 0.008501456146792876),
#  ('股权', 0.007779786496747262),
#  ('股东', 0.007757194890870173),
#  ('基金', 0.007744983261205823),
#  ('资产', 0.007263315759168126),
#  ('股份', 0.006956544179536613),
#  ('私募', 0.0068241442821451075),
#  ('股票', 0.00640797202805206),
#  ('持有', 0.006214373691812704),
#  ('转让', 0.006019342876710308),
#  ('投资者', 0.005608567983069231),
#  ('公告', 0.005512982369725599),
#  ('上市', 0.005484244861309482),
#  ('赎回', 0.005409341836067143),
#  ('债券', 0.005026242738346189),
#  ('募集', 0.005019856103975077),
#  ('交易', 0.004975214847668173)]
# '************************************************************'
# Most 20 Important words in TOPIC 36 :
#
# [('犯罪', 0.011960551868224647),
#  ('法院', 0.011931968011617179),
#  ('案件', 0.010187168511799493),
#  ('嫌疑', 0.010179986146565845),
#  ('嫌疑人', 0.01015242038060085),
#  ('检察', 0.009467712826067294),
#  ('民警', 0.009428707984909513),
#  ('警方', 0.009061679524930694),
#  ('公安', 0.008175705832506512),
#  ('罪嫌', 0.006974997549439778),
#  ('被告', 0.006861438935905441),
#  ('抓获', 0.006077868779471901),
#  ('盗窃', 0.005852250432193025),
#  ('检察院', 0.005774761289302403),
#  ('察院', 0.0057677390458986295),
#  ('被告人', 0.005736269271193023),
#  ('受贿', 0.005631514533799334),
#  ('涉嫌', 0.0054539960394905385),
#  ('人民法院', 0.005358019115605961),
#  ('公安局', 0.00535766896649718)]
# '************************************************************'
# Most 20 Important words in TOPIC 37 :
#
# [('事故', 0.02207990830421064),
#  ('交警', 0.018371437131119567),
#  ('司机', 0.017061963175200937),
#  ('一辆', 0.017049367364909758),
#  ('驾驶', 0.01676627443838146),
#  ('民警', 0.012881943449505844),
#  ('车辆', 0.012100121858770107),
#  ('货车', 0.011645308638006363),
#  ('行驶', 0.010717494288043517),
#  ('乘客', 0.009483716102468953),
#  ('轿车', 0.009388872311965633),
#  ('摩托车', 0.009347183255085207),
#  ('托车', 0.009341714741542653),
#  ('摩托', 0.009126915334780538),
#  ('交通事故', 0.008883498729301935),
#  ('驾驶员', 0.008851397724417705),
#  ('车祸', 0.008794076418519578),
#  ('通事', 0.008780537721055094),
#  ('车上', 0.008771903413619562),
#  ('男子', 0.008611131106921634)]
# '************************************************************'
# Most 20 Important words in TOPIC 38 :
#
# [('公交', 0.018393921397627182),
#  ('地铁', 0.015405907491470342),
#  ('路口', 0.014273401714423949),
#  ('交通', 0.013967987371770702),
#  ('线路', 0.012117917834395288),
#  ('路段', 0.011853203251298444),
#  ('高速', 0.011641248391154897),
#  ('车站', 0.010506177400691485),
#  ('铁路', 0.00929301903199831),
#  ('车辆', 0.009161740110124066),
#  ('列车', 0.008871440207149407),
#  ('大道', 0.008664745325316088),
#  ('停车', 0.008075522969236752),
#  ('换乘', 0.0074718276476732565),
#  ('道路', 0.007288930093602066),
#  ('动车', 0.007057415641093469),
#  ('施工', 0.006918789143213057),
#  ('公路', 0.006906628650017212),
#  ('站点', 0.006669069696709875),
#  ('高铁', 0.006547014962975169)]
# '************************************************************'
